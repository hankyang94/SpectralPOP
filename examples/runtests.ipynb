# %%
println("****Test polynomial optimization****")

using DynamicPolynomials

@polyvar x[1:2] # variables

f=x[1]^2+0.5*x[1]*x[2]-0.25*x[2]^2+0.75*x[1]-0.3*x[2] # objective function

R=1.0 # squared radius of a sphere constraint
h=[R-sum(x.^2);(x[1]-1.0)*x[2]] # equality constraints (including the sphere constraint)

k=2 # relaxed order

include("../src/SpectralPOP.jl")
using .SpectralPOP

g=Vector{Polynomial{true,Float64}}([])
opt_val = SpectralPOP.SumofSquares_POP_WithExtraction(x,f,g,h,k) # SumOfSquares.jl + Mosek
println()
println(".................................")
println()


# get approximations of the optimal value and an optimal solution
opt_val,opt_sol = SpectralPOP.CTP_POP(x,f,h,k,R,method="LMBM",EigAlg="Arpack",tol=1e-5)# Limited Memory Bundle Method
println()
println(".................................")
println()
opt_val,opt_sol = SpectralPOP.CTP_POP(x,f,h,k,R,method="SketchyCGAL",EigAlg="Normal",tol=1e-3)# Limited Memory Bundle Method
# Out:
# ****Test polynomial optimization****
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=0.2499999989810142
# Atomic measure on the variables x[1], x[2] with 1 atoms:
#  at [-1.000000003373059, 0.0] with weight 0.9999999960287472
#   0.015505 seconds (10.15 k allocations: 1.167 MiB)
#
# .................................
# WARNING: replacing module SpectralPOP.
# WARNING: using SpectralPOP.CTP_POP in module Main conflicts with an existing identifier.
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=6
#   Number of equality trace constraints: m=19
#   0.074459 seconds (51.50 k allocations: 2.595 MiB, 32.39% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       19
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        18
# N. func. eval.:  21
# Final value:     -0.250000
# Execution time:  0.061455
#   0.210438 seconds (255.50 k allocations: 14.494 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=0.24999969546589917
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [-0.9999869163168831, -9.516753087602626e-5]
#   check gap of lower bound  = 6.008123930251186e-5
#   check equality constraint 1 = 2.615813819217827e-5
#   check equality constraint 2 = 0.00019033381661023554
# ####################################
# Optimal solution: opt_sol = [-0.9999869163168831, -9.516753087602626e-5]
# ####################################
#   0.000589 seconds (1.28 k allocations: 42.375 KiB)
#   0.285925 seconds (309.33 k allocations: 17.152 MiB, 8.44% gc time)
#
# .................................
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=6
#   Number of equality trace constraints: m=19
#   0.000236 seconds (1.00 k allocations: 74.156 KiB)
# **SketchyCGAL solver:
# - SketchyCGAL SDP Solver - Beta.V.0.0
# --------------------------
#  iter=1
#  stopObj=4.105237911414446
#  stopFeas=1.0
#  primalObj=-0.3411397300361804
# --------------------------
#  iter=2
#  stopObj=36.90582310320491
#  stopFeas=3.964197172243201
#  primalObj=-0.37305019591401667
# --------------------------
#  iter=4
#  stopObj=11.872481902069305
#  stopFeas=1.6719649046596226
#  primalObj=0.667863624651389
# --------------------------
#  iter=8
#  stopObj=5.348647898985477
#  stopFeas=0.5944692238281051
#  primalObj=0.5720693116527036
# --------------------------
#  iter=16
#  stopObj=3.4373207067569282
#  stopFeas=0.34023229521656495
#  primalObj=0.7040377013327512
# --------------------------
#  iter=32
#  stopObj=1.0267224166767395
#  stopFeas=0.11512634253892096
#  primalObj=0.5740729747964621
# --------------------------
#  iter=64
#  stopObj=1.4046217146602071
#  stopFeas=0.07349886276824225
#  primalObj=0.6349719291302531
# --------------------------
#  iter=128
#  stopObj=1.1576436238906984
#  stopFeas=0.03848257072944923
#  primalObj=0.6191837044814221
# --------------------------
#  iter=256
#  stopObj=0.40963848927117086
#  stopFeas=0.011725683686799345
#  primalObj=0.5040595531988482
# --------------------------
#  iter=512
#  stopObj=0.21765030266066765
#  stopFeas=0.005627792167914748
#  primalObj=0.4477951384138537
# --------------------------
#  iter=1024
#  stopObj=0.16269165154355514
#  stopFeas=0.0035765442722206467
#  primalObj=0.40750735821589096
# --------------------------
#  iter=2048
#  stopObj=0.4117456518850998
#  stopFeas=0.005158604566028941
#  primalObj=0.42603242386941953
# --------------------------
#  iter=4096
#  stopObj=0.35742590599030993
#  stopFeas=0.002599069281356836
#  primalObj=0.4730657071132532
# --------------------------
#  iter=8192
#  stopObj=0.2642545904525816
#  stopFeas=0.0017564962789491318
#  primalObj=0.5021624659805618
# * status = stopping criteria met
#   0.845836 seconds (4.73 M allocations: 554.629 MiB, 11.69% gc time)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=0.5414812205850467
# ====================================
# Rank of moment matrix = 6
#   0.145615 seconds (335.81 k allocations: 16.967 MiB)
#   0.992359 seconds (5.07 M allocations: 571.701 MiB, 9.96% gc time)
# (0.5414812205850467, Array{Float64,1}[])

# %%
println("****Test polynomial system****")

using DynamicPolynomials

@polyvar x[1:2] # variables

# mickey equations
h=[x[1]^2 + 4*x[2]^2 - 4;
        2*x[2]^2 - x[1]]

L=10 # squared radius of a ball centered at origin containing at least one real root
k=1 # relaxed order

include("../src/SpectralPOP.jl")
using .SpectralPOP

# get a real root
root = SpectralPOP.ASC_PolySys(x,h,k,L,method="LMBM",EigAlg="Arpack",tol=1e-5)
# Out:
# ****Test polynomial system****
# ------------------------------------
# Determine omega1:
# WARNING: replacing module SpectralPOP.
# WARNING: using SpectralPOP.CTP_POP in module Main conflicts with an existing identifier.
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=4
#   0.049962 seconds (51.25 k allocations: 2.571 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       4
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     3
# N. iter.:        244
# N. func. eval.:  2092
# Final value:     -1.218241
# Execution time:  0.166794
#   0.323210 seconds (468.61 k allocations: 25.995 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=1.218240666866828
# ====================================
# Dimension of the null space of Gram matrix = 3
#   0.000164 seconds (180 allocations: 13.938 KiB)
#   0.380661 seconds (521.67 k allocations: 28.640 MiB)
# omega1 = 1.218240666866828
# ------------------------------------
# ------------------------------------
# Determine omega2:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=5
#   0.000465 seconds (940 allocations: 67.484 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       5
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     3
# N. iter.:        59
# N. func. eval.:  206
# Final value:     -1.502764
# Execution time:  0.009544
#   0.014243 seconds (22.91 k allocations: 1.192 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=1.5027641555169873
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [0.39196922461675693, 0.2497251484950383, 0.0]
#   check gap of lower bound  = 0.7862119296695333
#   check equality constraint 1 = 0.7839974771624694
#   check equality constraint 2 = 0.0030904722101374182
#   check equality constraint 3 = 0.0007737473338286782
#   check equality constraint 4 = 0.7861765932628113
#   0.000721 seconds (1.12 k allocations: 37.531 KiB)
#   0.015888 seconds (25.96 k allocations: 1.315 MiB)
# omega2 = 1.5027641555169873
# ------------------------------------
# ------------------------------------
# Determine omega3:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=6
#   0.000243 seconds (826 allocations: 58.844 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       6
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        8
# N. func. eval.:  8
# Final value:     -0.227539
# Execution time:  0.000587
#   0.001243 seconds (2.53 k allocations: 84.078 KiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=0.22753890343624888
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [0.3908347449078756, 0.2485901169315699, 0.8862422260914993]
#   check gap of lower bound  = 4.922824837555462e-5
#   check equality constraint 1 = 2.5872629128120828e-5
#   check equality constraint 2 = 6.0017228589337446e-5
#   check equality constraint 3 = 1.294208124988372e-6
#   check equality constraint 4 = 6.397068829266939e-5
#   check equality constraint 5 = 2.9737990744793663e-5
# ####################################
# Optimal solution: opt_sol = [0.3908347449078756, 0.2485901169315699, 0.8862422260914993]
# ####################################
#   0.000866 seconds (1.72 k allocations: 49.578 KiB)
#   0.002766 seconds (6.07 k allocations: 216.609 KiB)
# omega3 = 0.22753890343624888
# ------------------------------------
# ------
#   0.896065 seconds (970.62 k allocations: 50.980 MiB)
#   1.323091 seconds (1.31 M allocations: 68.346 MiB, 2.91% gc time)
# 2-element Array{Float64,1}:
#  1.2359279826397824
#  0.7861109733113487

# %%
include("../test/runtests.jl")
# Out:
# ****Test polynomial optimization****
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=0.2499999989810142
# Atomic measure on the variables x[1], x[2] with 1 atoms:
#  at [-1.000000003373059, 0.0] with weight 0.9999999960287472
#   0.072762 seconds (10.28 k allocations: 1.173 MiB)
#
# .................................
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=6
#   Number of equality trace constraints: m=19
#   0.000352 seconds (1.00 k allocations: 74.156 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       19
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        18
# N. func. eval.:  21
# Final value:     -0.250000
# Execution time:  0.002457
#   0.003686 seconds (4.19 k allocations: 201.234 KiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=0.24999969546589926
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [-0.9999869163169004, -9.516753083954225e-5]
#   check gap of lower bound  = 6.0081239294934585e-5
#   check equality constraint 1 = 2.6158138157539312e-5
#   check equality constraint 2 = 0.00019033381653726962
# ####################################
# Optimal solution: opt_sol = [-0.9999869163169004, -9.516753083954225e-5]
# ####################################
#   0.001078 seconds (1.28 k allocations: 41.219 KiB)
#   0.005696 seconds (7.48 k allocations: 340.313 KiB)
#
# .................................
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=6
#   Number of equality trace constraints: m=19
#   0.000589 seconds (1.00 k allocations: 74.156 KiB)
# **SketchyCGAL solver:
# - SketchyCGAL SDP Solver - Beta.V.0.0
# --------------------------
#  iter=1
#  stopObj=1.7815617347472985
#  stopFeas=1.0
#  primalObj=0.19989049493325656
# --------------------------
#  iter=2
#  stopObj=19.280839105544818
#  stopFeas=2.87953695913079
#  primalObj=0.3026605550114232
# --------------------------
#  iter=4
#  stopObj=8.366525097370857
#  stopFeas=1.3420312823913458
#  primalObj=-0.0373461146823854
# --------------------------
#  iter=8
#  stopObj=7.810778360442837
#  stopFeas=0.9634433398951354
#  primalObj=0.11739412416904263
# --------------------------
#  iter=16
#  stopObj=4.052812623358054
#  stopFeas=0.4386508794176774
#  primalObj=0.38768759305396017
# --------------------------
#  iter=32
#  stopObj=1.9043039520109186
#  stopFeas=0.14541651074994852
#  primalObj=0.6267251541757902
# --------------------------
#  iter=64
#  stopObj=0.10667395191868201
#  stopFeas=0.0729181939277034
#  primalObj=0.7134632499260155
# --------------------------
#  iter=128
#  stopObj=1.0486595699989967
#  stopFeas=0.032941995583448756
#  primalObj=0.614181521267878
# --------------------------
#  iter=256
#  stopObj=0.410267286993766
#  stopFeas=0.012679052212428243
#  primalObj=0.5336873340778058
# --------------------------
#  iter=512
#  stopObj=1.0244653504769445
#  stopFeas=0.01728756834100097
#  primalObj=0.4152493828785266
# --------------------------
#  iter=1024
#  stopObj=-0.32423201841528493
#  stopFeas=0.003912197499596318
#  primalObj=0.405289346153988
# --------------------------
#  iter=2048
#  stopObj=-0.8973938653615228
#  stopFeas=0.002378091246526662
#  primalObj=0.4363782020672727
# --------------------------
#  iter=4096
#  stopObj=0.23635325018015407
#  stopFeas=0.0023355167955637795
#  primalObj=0.46575778092943154
# --------------------------
#  iter=8192
#  stopObj=0.12038494063791516
#  stopFeas=0.0014067919781991405
#  primalObj=0.5153264092345603
# * status = stopping criteria met
#   0.925610 seconds (4.56 M allocations: 537.753 MiB, 13.76% gc time)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=0.5486822852407874
# ====================================
# Rank of moment matrix = 6
#   0.000038 seconds (79 allocations: 4.859 KiB)
#   0.926751 seconds (4.57 M allocations: 537.854 MiB, 13.75% gc time)
#
#
#
#
#
# ****Test polynomial system****
# ------------------------------------
# Determine omega1:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=4
#   0.000180 seconds (753 allocations: 51.234 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       4
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     3
# N. iter.:        185
# N. func. eval.:  939
# Final value:     -1.218242
# Execution time:  0.045929
#   0.046724 seconds (98.39 k allocations: 5.267 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=1.2182419568099605
# ====================================
# Dimension of the null space of Gram matrix = 3
#   0.000132 seconds (178 allocations: 13.047 KiB)
#   0.047433 seconds (100.32 k allocations: 5.351 MiB)
# omega1 = 1.2182419568099605
# ------------------------------------
# ------------------------------------
# Determine omega2:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=5
#   0.000189 seconds (788 allocations: 54.484 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       5
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        56
# N. func. eval.:  158
# Final value:     -1.502791
# Execution time:  0.007706
#   0.008333 seconds (17.96 k allocations: 944.109 KiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=1.5027911095596238
# ====================================
# Dimension of the null space of Gram matrix = 2
#   0.000113 seconds (173 allocations: 12.313 KiB)
#   0.009011 seconds (19.92 k allocations: 1.008 MiB)
# omega2 = 1.5027911095596238
# ------------------------------------
# ------------------------------------
# Determine omega3:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=6
#   0.000173 seconds (826 allocations: 58.844 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       6
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        8
# N. func. eval.:  8
# Final value:     -0.227533
# Execution time:  0.000473
#   0.001103 seconds (2.53 k allocations: 86.578 KiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=0.22753317728547398
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [0.3908347715741779, 0.2485845718508518, 0.886247607209278]
#   check gap of lower bound  = 4.746238614819487e-5
#   check equality constraint 1 = 1.9070682118260684e-5
#   check equality constraint 2 = 7.10238794748852e-5
#   check equality constraint 3 = 4.22797206078851e-6
#   check equality constraint 4 = 6.942935956544272e-5
#   check equality constraint 5 = 2.0676056554314037e-5
# ####################################
# Optimal solution: opt_sol = [0.3908347715741779, 0.2485845718508518, 0.886247607209278]
# ####################################
#   0.000696 seconds (1.72 k allocations: 49.547 KiB)
#   0.002337 seconds (6.07 k allocations: 216.141 KiB)
# omega3 = 0.22753317728547398
# ------------------------------------
# ------
#   0.059635 seconds (129.13 k allocations: 6.704 MiB)
#   0.059847 seconds (130.00 k allocations: 6.744 MiB)
# 2-element Array{Float64,1}:
#  1.2359280669660344
#  0.78609343822647

# %%
include("../test/poly_opt/test_random_dense_quadratic_on_sphere.jl")
# Out:
# ***Problem setting***
# Number of variable: n=50
# ====================
# Number of equality constraints: l=1
# ====================
# Relaxed order: k=1
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-5.873973816551189
#   0.502621 seconds (471.24 k allocations: 59.012 MiB, 3.39% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=51
#   Number of equality trace constraints: m=2
#   0.026819 seconds (63.91 k allocations: 24.812 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       2
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        7
# N. func. eval.:  7
# Final value:     5.873974
# Execution time:  0.005829
#   0.006596 seconds (4.39 k allocations: 759.219 KiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-5.873974243380616
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [0.044445344977203746, 0.10221104604882149, -0.045119629036360846, 0.26955845259180516, -0.16833773576082747, -0.13373685360843202, -0.10476419394137086, -0.29068953832351513, 0.10674779523814622, 0.09764695410662877, -0.09552709405288115, 0.10119542895214949, -0.10001809609366648, -0.12010543891627806, -0.08615336831836111, 0.16806416286755602, -0.0807574318708452, -0.2896047780103357, 0.19172601532831676, -0.16690246916597423, 0.08412871948922196, 0.1326169600372724, -0.10121464762122191, 0.10038147642673692, 0.03619907454407209, 0.12397541185675195, -0.0028441159327920232, 0.15930005120690863, -0.10618525663321574, -0.11636173982591597, 0.14398463059275024, -0.15602993357889516, 0.3116574842586271, 0.04208111696280204, 0.13381295933353898, 0.19817021117712474, -0.07359195681722526, -0.08046065914355119, -0.08152849862931001, 0.14360015003056442, 0.03549384987581296, 0.02842176860310979, 0.05758028578772248, 0.15735250667139997, 0.1169414674931029, 0.1859472486428403, -0.19406387553380663, -0.03984071869305891, 0.01922467646008627, 0.21747743612309]
#   check gap of lower bound  = 0.007648051324665062
#   check equality constraint 1 = 0.0017076875381589751
# ####################################
# Optimal solution: opt_sol = [0.044445344977203746, 0.10221104604882149, -0.045119629036360846, 0.26955845259180516, -0.16833773576082747, -0.13373685360843202, -0.10476419394137086, -0.29068953832351513, 0.10674779523814622, 0.09764695410662877, -0.09552709405288115, 0.10119542895214949, -0.10001809609366648, -0.12010543891627806, -0.08615336831836111, 0.16806416286755602, -0.0807574318708452, -0.2896047780103357, 0.19172601532831676, -0.16690246916597423, 0.08412871948922196, 0.1326169600372724, -0.10121464762122191, 0.10038147642673692, 0.03619907454407209, 0.12397541185675195, -0.0028441159327920232, 0.15930005120690863, -0.10618525663321574, -0.11636173982591597, 0.14398463059275024, -0.15602993357889516, 0.3116574842586271, 0.04208111696280204, 0.13381295933353898, 0.19817021117712474, -0.07359195681722526, -0.08046065914355119, -0.08152849862931001, 0.14360015003056442, 0.03549384987581296, 0.02842176860310979, 0.05758028578772248, 0.15735250667139997, 0.1169414674931029, 0.1859472486428403, -0.19406387553380663, -0.03984071869305891, 0.01922467646008627, 0.21747743612309]
# ####################################
#   0.007704 seconds (10.60 k allocations: 1.122 MiB)
#   0.041653 seconds (79.90 k allocations: 26.697 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=51
#   Number of equality trace constraints: m=2
#   0.034409 seconds (63.91 k allocations: 24.812 MiB)
# **SketchyCGAL solver:
# - SketchyCGAL SDP Solver - Beta.V.0.0
# --------------------------
#  iter=1
#  stopObj=6.21461413070915
#  stopFeas=1.0
#  primalObj=-6.577350403591438
# --------------------------
#  iter=2
#  stopObj=7.018392493019853
#  stopFeas=1.6915703336542183
#  primalObj=-3.3066078602660367
# --------------------------
#  iter=4
#  stopObj=4.1840795961142785
#  stopFeas=0.717348017715044
#  primalObj=-3.7982463977866607
# --------------------------
#  iter=8
#  stopObj=3.518355513877168
#  stopFeas=0.41696445411341904
#  primalObj=-4.544588167570802
# --------------------------
#  iter=16
#  stopObj=1.6529862097194377
#  stopFeas=0.1437973030881254
#  primalObj=-5.037731565293549
# --------------------------
#  iter=32
#  stopObj=0.28799685655472107
#  stopFeas=0.0019820947507131347
#  primalObj=-5.595850623381011
# --------------------------
#  iter=64
#  stopObj=0.16647856865381438
#  stopFeas=0.006758540651770942
#  primalObj=-5.715111907586509
# --------------------------
#  iter=128
#  stopObj=0.045255940304369524
#  stopFeas=0.0003759650428713936
#  primalObj=-5.826811650215067
# --------------------------
#  iter=256
#  stopObj=0.01268022577463146
#  stopFeas=0.00010411101921712979
#  primalObj=-5.8613517390830525
# * status = stopping criteria met
#   0.265379 seconds (235.77 k allocations: 219.985 MiB, 19.71% gc time)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-5.866663131578231
# ====================================
# Rank of moment matrix = 51
#   0.000137 seconds (175 allocations: 135.516 KiB)
#   0.300433 seconds (300.89 k allocations: 244.972 MiB, 17.41% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ***Problem setting***
# Number of variable: n=75
# ====================
# Number of equality constraints: l=1
# ====================
# Relaxed order: k=1
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-7.949887872799342
#   2.986897 seconds (1.09 M allocations: 149.642 MiB, 1.19% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=76
#   Number of equality trace constraints: m=2
#   0.117056 seconds (149.51 k allocations: 86.474 MiB, 18.03% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       2
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        6
# N. func. eval.:  6
# Final value:     7.949888
# Execution time:  0.006119
#   0.006847 seconds (4.59 k allocations: 1.170 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-7.949887910752048
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [0.022705325482639697, -0.004306836392182482, -0.17657901526461908, -0.03574616988030944, 0.17041737761129472, 0.16307576853528943, -0.05326153800883602, -0.004730727502319394, -0.03790219944164219, 0.0009291200933197027, -0.11787681344220777, -0.048272499854627414, -0.06401487421690429, -0.037154876109682905, -0.028540801186404483, 0.07442697197381848, 0.04210054819879645, 0.10948328001648855, 0.1938593422509743, -0.0921722937241661, -0.06137603674668921, -0.27313226097859994, 0.03606507378836813, 0.02741724029888102, -0.03770428159990291, -0.08952967579301965, -0.1498135070764158, -0.20811120314467002, -0.05697429237647258, 0.13239316902138734, -0.08274007935291496, -0.20712997673823857, 0.09641755339649201, -0.15293553001335275, 0.07698952428962015, 0.022343050225551005, -0.051829087787781766, -0.1084952182156767, 0.20643340023467607, -0.20105146182779246, 0.1849711642941933, 0.21932060348604068, -0.049527119364910485, -0.09770740192570558, 0.10976565430256392, -0.1571473915781708, -0.12259080686377098, -0.13374114506481333, 0.03353543018992726, -0.03017219281732066, -0.03463376498638335, 0.0820498572362471, -0.13461121024650216, 0.112872427733609, 0.043005409571603585, 0.0180030776043126, -0.01824589232102177, -0.005907931384365667, -0.026497165235344282, 0.10139074291856513, -0.07086673427820099, -0.00017828844497358565, -0.02906193770177252, -0.04769146418821409, -0.2496429480481937, -0.03928441783562532, -0.15113995086396648, 0.03472272343060402, -0.0033128126666085254, -0.15750247288346161, 0.22340897197129894, 0.07934395322727623, -0.10360354065116889, -0.04738511746011938, 0.22008016581954107]
#   check gap of lower bound  = 0.0020342258470780195
#   check equality constraint 1 = 0.00037873905156571297
# ####################################
# Optimal solution: opt_sol = [0.022705325482639697, -0.004306836392182482, -0.17657901526461908, -0.03574616988030944, 0.17041737761129472, 0.16307576853528943, -0.05326153800883602, -0.004730727502319394, -0.03790219944164219, 0.0009291200933197027, -0.11787681344220777, -0.048272499854627414, -0.06401487421690429, -0.037154876109682905, -0.028540801186404483, 0.07442697197381848, 0.04210054819879645, 0.10948328001648855, 0.1938593422509743, -0.0921722937241661, -0.06137603674668921, -0.27313226097859994, 0.03606507378836813, 0.02741724029888102, -0.03770428159990291, -0.08952967579301965, -0.1498135070764158, -0.20811120314467002, -0.05697429237647258, 0.13239316902138734, -0.08274007935291496, -0.20712997673823857, 0.09641755339649201, -0.15293553001335275, 0.07698952428962015, 0.022343050225551005, -0.051829087787781766, -0.1084952182156767, 0.20643340023467607, -0.20105146182779246, 0.1849711642941933, 0.21932060348604068, -0.049527119364910485, -0.09770740192570558, 0.10976565430256392, -0.1571473915781708, -0.12259080686377098, -0.13374114506481333, 0.03353543018992726, -0.03017219281732066, -0.03463376498638335, 0.0820498572362471, -0.13461121024650216, 0.112872427733609, 0.043005409571603585, 0.0180030776043126, -0.01824589232102177, -0.005907931384365667, -0.026497165235344282, 0.10139074291856513, -0.07086673427820099, -0.00017828844497358565, -0.02906193770177252, -0.04769146418821409, -0.2496429480481937, -0.03928441783562532, -0.15113995086396648, 0.03472272343060402, -0.0033128126666085254, -0.15750247288346161, 0.22340897197129894, 0.07934395322727623, -0.10360354065116889, -0.04738511746011938, 0.22008016581954107]
# ####################################
#   0.012838 seconds (17.69 k allocations: 2.981 MiB)
#   0.137398 seconds (172.97 k allocations: 90.657 MiB, 15.36% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=76
#   Number of equality trace constraints: m=2
#   0.150976 seconds (149.51 k allocations: 86.474 MiB, 26.90% gc time)
# **SketchyCGAL solver:
# - SketchyCGAL SDP Solver - Beta.V.0.0
# --------------------------
#  iter=1
#  stopObj=7.79061171376064
#  stopFeas=1.0
#  primalObj=-8.369298263046847
# --------------------------
#  iter=2
#  stopObj=10.136400675806867
#  stopFeas=2.0330177010438675
#  primalObj=-5.056755007234033
# --------------------------
#  iter=4
#  stopObj=4.271960486560539
#  stopFeas=0.6901183105723456
#  primalObj=-6.071410866448723
# --------------------------
#  iter=8
#  stopObj=0.7793149068556353
#  stopFeas=0.02235366443925096
#  primalObj=-7.286154299687002
# --------------------------
#  iter=16
#  stopObj=0.3669012541023662
#  stopFeas=0.04593816297570091
#  primalObj=-7.680718848557683
# --------------------------
#  iter=32
#  stopObj=0.06859184337297997
#  stopFeas=0.011733488360557032
#  primalObj=-7.840494216342008
# --------------------------
#  iter=64
#  stopObj=0.041052691772605954
#  stopFeas=0.0004247291522100896
#  primalObj=-7.910011416924325
# * status = stopping criteria met
#   0.197067 seconds (83.96 k allocations: 135.724 MiB, 12.79% gc time)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-7.937313071612002
# ====================================
# Rank of moment matrix = 76
#   0.000273 seconds (223 allocations: 295.109 KiB)
#   0.349238 seconds (234.96 k allocations: 222.582 MiB, 18.84% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ***Problem setting***
# Number of variable: n=100
# ====================
# Number of equality constraints: l=1
# ====================
# Relaxed order: k=1
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# InterruptException:
#
# Stacktrace:
#  [1] sigatomic_end at ./c.jl:0 [inlined]
#  [2] disable_sigint at ./c.jl:448 [inlined]
#  [3] optimize(::Mosek.Task) at /home/hoanganh/.julia/packages/Mosek/6LuE3/src/msk_functions.jl:5486
#  [4] optimize!(::MosekTools.MosekModel) at /home/hoanganh/.julia/packages/MosekTools/prFdq/src/MosekTools.jl:282
#  [5] optimize!(::MathOptInterface.Bridges.LazyBridgeOptimizer{MosekTools.MosekModel}) at /home/hoanganh/.julia/packages/MathOptInterface/bygN7/src/Bridges/bridge_optimizer.jl:239
#  [6] optimize!(::MathOptInterface.Utilities.CachingOptimizer{MathOptInterface.AbstractOptimizer,MathOptInterface.Utilities.UniversalFallback{MathOptInterface.Utilities.Model{Float64}}}) at /home/hoanganh/.julia/packages/MathOptInterface/bygN7/src/Utilities/cachingoptimizer.jl:189
#  [7] #optimize!#97(::Bool, ::Bool, ::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::typeof(JuMP.optimize!), ::JuMP.Model, ::Nothing) at /home/hoanganh/.julia/packages/JuMP/YXK4e/src/optimizer_interface.jl:131
#  [8] macro expansion at /home/hoanganh/.julia/packages/JuMP/YXK4e/src/optimizer_interface.jl:107 [inlined]
#  [9] macro expansion at ./util.jl:155 [inlined]
#  [10] SumofSquares_POP(::Array{PolyVar{true},1}, ::Polynomial{true,Float64}, ::Array{Polynomial{true,Float64},1}, ::Array{Polynomial{true,Float64},1}, ::Int64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_SumOfSquares.jl:2
#  [11] test(::Int64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/test/poly_opt/test_random_dense_quadratic_on_sphere.jl:55
#  [12] top-level scope at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/test/poly_opt/test_random_dense_quadratic_on_sphere.jl:82
#  [13] include at ./boot.jl:328 [inlined]
#  [14] include_relative(::Module, ::String) at ./loading.jl:1105
#  [15] include(::Module, ::String) at ./Base.jl:31
#  [16] include(::String) at ./client.jl:424
#  [17] top-level scope at In[9]:1

# %%
include("../test/poly_opt/test_random_dense_equality_constrained_QCQP_on_sphere_first_order.jl")
# Out:
# ***Problem setting***
# Number of variable: n=50
# ====================
# Number of equality constraints: l_h=14
# ====================
# Relaxed order: k=1
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-4.911823405794787
#   0.695218 seconds (844.52 k allocations: 106.116 MiB, 5.85% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=51
#   Number of equality trace constraints: m=15
#   0.166191 seconds (327.85 k allocations: 134.906 MiB, 11.58% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       15
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        24
# N. func. eval.:  26
# Final value:     4.911827
# Execution time:  0.026123
#   0.027238 seconds (12.48 k allocations: 2.690 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-4.911826965274397
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [-0.2025702486640467, -0.12650731770524382, 0.1481057653095589, 0.0560131264855537, -0.019779488938108467, 0.01639184115716169, 0.18745211799345948, 0.22887452166472874, -0.0033145338821486394, 0.1227897916997835, 0.013163809455218084, -0.02383978461820082, 0.035921418668395544, 0.21725139683939465, -0.10974072311557909, -0.1519103972963311, -0.013832818127791241, -0.09791043181196558, 0.01673138396994217, -0.09925305446831754, -0.04361630345020939, -0.17368369765696948, 0.019971244708549444, 0.35273731345873544, 0.01301573782576678, -0.0060008962825534255, 0.12857830977575166, -0.01837881638008809, -0.021574299017242008, -0.0952587441913376, 0.11449195769126583, -0.22448020047319076, -0.2015164636719548, -0.07503578360035319, -0.17307683236352925, 0.02510399792144054, -0.29000837255714285, -0.10937273118996965, -0.1679694873310675, 0.00112049232842676, 0.16678230000458522, 0.1166345305869355, 0.13581774113865694, -0.08369227386297759, 0.008672840516410799, -0.10245994304924412, -0.15152659503329194, 0.2812748877454317, 0.09899126133240548, 0.2693180743511993]
#   check gap of lower bound  = 0.0015638379644054012
#   check equality constraint 1 = 0.0003948396940028909
#   check equality constraint 2 = 0.0003107035276512793
#   check equality constraint 3 = 0.0007647608319179336
#   check equality constraint 4 = 0.0018158739299817817
#   check equality constraint 5 = 0.00173999743007891
#   check equality constraint 6 = 0.001116880538844539
#   check equality constraint 7 = 0.0006577948613882625
#   check equality constraint 8 = 0.0002896319049069396
#   check equality constraint 9 = 0.0016534826116067353
#   check equality constraint 10 = 0.00030820388947411237
#   check equality constraint 11 = 9.382326676327102e-5
#   check equality constraint 12 = 0.0011750158515756656
#   check equality constraint 13 = 0.0004073096611831306
#   check equality constraint 14 = 0.001772133958337821
# ####################################
# Optimal solution: opt_sol = [-0.2025702486640467, -0.12650731770524382, 0.1481057653095589, 0.0560131264855537, -0.019779488938108467, 0.01639184115716169, 0.18745211799345948, 0.22887452166472874, -0.0033145338821486394, 0.1227897916997835, 0.013163809455218084, -0.02383978461820082, 0.035921418668395544, 0.21725139683939465, -0.10974072311557909, -0.1519103972963311, -0.013832818127791241, -0.09791043181196558, 0.01673138396994217, -0.09925305446831754, -0.04361630345020939, -0.17368369765696948, 0.019971244708549444, 0.35273731345873544, 0.01301573782576678, -0.0060008962825534255, 0.12857830977575166, -0.01837881638008809, -0.021574299017242008, -0.0952587441913376, 0.11449195769126583, -0.22448020047319076, -0.2015164636719548, -0.07503578360035319, -0.17307683236352925, 0.02510399792144054, -0.29000837255714285, -0.10937273118996965, -0.1679694873310675, 0.00112049232842676, 0.16678230000458522, 0.1166345305869355, 0.13581774113865694, -0.08369227386297759, 0.008672840516410799, -0.10245994304924412, -0.15152659503329194, 0.2812748877454317, 0.09899126133240548, 0.2693180743511993]
# ####################################
#   0.012868 seconds (13.60 k allocations: 1.200 MiB)
#   0.207084 seconds (355.12 k allocations: 138.827 MiB, 9.29% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=51
#   Number of equality trace constraints: m=15
#   0.238807 seconds (327.85 k allocations: 134.906 MiB, 28.45% gc time)
# **SketchyCGAL solver:
# - SketchyCGAL SDP Solver - Beta.V.0.0
# --------------------------
#  iter=1
#  stopObj=6.543956840245217
#  stopFeas=1.0
#  primalObj=-7.233853189343225
# --------------------------
#  iter=2
#  stopObj=48.684029348200625
#  stopFeas=3.6795734952593975
#  primalObj=-3.329883126009192
# --------------------------
#  iter=4
#  stopObj=42.901787659797996
#  stopFeas=2.7581182770413197
#  primalObj=-1.4069095953852713
# --------------------------
#  iter=8
#  stopObj=12.253466554335724
#  stopFeas=0.9739131116591524
#  primalObj=-0.597209399604622
# --------------------------
#  iter=16
#  stopObj=9.33662785654954
#  stopFeas=0.47020460117212565
#  primalObj=-0.9003277484353261
# --------------------------
#  iter=32
#  stopObj=8.657896817809775
#  stopFeas=0.35613412651196635
#  primalObj=-1.8536354500598042
# --------------------------
#  iter=64
#  stopObj=3.277716034824766
#  stopFeas=0.0732922515610917
#  primalObj=-3.2422114096848826
# --------------------------
#  iter=128
#  stopObj=1.224171641814924
#  stopFeas=0.028872317308876017
#  primalObj=-4.047248460098672
# --------------------------
#  iter=256
#  stopObj=0.6670691580208068
#  stopFeas=0.010371301972305645
#  primalObj=-4.526933282678765
# --------------------------
#  iter=512
#  stopObj=0.2691643660459251
#  stopFeas=0.0037545340694202984
#  primalObj=-4.745257974143488
# --------------------------
#  iter=1024
#  stopObj=0.0934253679332544
#  stopFeas=0.0011483993364755796
#  primalObj=-4.842233598612148
# * status = stopping criteria met
#   2.597620 seconds (1.02 M allocations: 7.088 GiB, 13.71% gc time)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-4.853314424663273
# ====================================
# Rank of moment matrix = 51
#   0.000126 seconds (175 allocations: 135.750 KiB)
#   2.837556 seconds (1.35 M allocations: 7.220 GiB, 14.94% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ***Problem setting***
# Number of variable: n=60
# ====================
# Number of equality constraints: l_h=16
# ====================
# Relaxed order: k=1
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-5.8358537680044025
#   1.826199 seconds (1.30 M allocations: 169.021 MiB, 2.30% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=61
#   Number of equality trace constraints: m=17
#   0.336623 seconds (550.40 k allocations: 259.145 MiB, 11.67% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       17
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     3
# N. iter.:        181
# N. func. eval.:  292
# Final value:     5.835854
# Execution time:  0.358566
#   0.359857 seconds (155.35 k allocations: 36.613 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-5.835853748656142
# ====================================
# Dimension of the null space of Gram matrix = 2
#   0.002769 seconds (753 allocations: 411.594 KiB)
#   0.699940 seconds (707.68 k allocations: 296.192 MiB, 5.61% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=61
#   Number of equality trace constraints: m=17
#   0.339117 seconds (550.40 k allocations: 259.144 MiB, 15.96% gc time)
# **SketchyCGAL solver:
# - SketchyCGAL SDP Solver - Beta.V.0.0
# --------------------------
#  iter=1
#  stopObj=7.201210046315022
#  stopFeas=1.0
#  primalObj=-7.3979223207468765
# --------------------------
#  iter=2
#  stopObj=66.82484988468052
#  stopFeas=3.537606637531389
#  primalObj=-3.423748417214093
# --------------------------
#  iter=4
#  stopObj=59.26346712155485
#  stopFeas=3.242071392545862
#  primalObj=-2.376905651932918
# --------------------------
#  iter=8
#  stopObj=19.943422588865964
#  stopFeas=1.109195656068977
#  primalObj=-2.2771832760132815
# --------------------------
#  iter=16
#  stopObj=10.727551494277895
#  stopFeas=0.3789500667244378
#  primalObj=-2.288554822832625
# --------------------------
#  iter=32
#  stopObj=11.745859336170346
#  stopFeas=0.30103526433901945
#  primalObj=-3.0840550155664954
# --------------------------
#  iter=64
#  stopObj=4.463232952428693
#  stopFeas=0.09327249185572659
#  primalObj=-3.826653662488912
# --------------------------
#  iter=128
#  stopObj=2.38101076129095
#  stopFeas=0.03614347826244143
#  primalObj=-4.478827752863291
# --------------------------
#  iter=256
#  stopObj=4.358618115185636
#  stopFeas=0.04137132943176921
#  primalObj=-5.040583562280393
# --------------------------
#  iter=512
#  stopObj=2.4205847997342964
#  stopFeas=0.020346021794707587
#  primalObj=-5.406062481499206
# InterruptException:
#
# Stacktrace:
#  [1] copy at ./array.jl:325 [inlined]
#  [2] -(::SparseArrays.SparseMatrixCSC{Float64,Int64}) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SparseArrays/src/sparsematrix.jl:1631
#  [3] (::SpectralPOP.var"#Primitive2#34"{Bool,Int64,SparseArrays.SparseMatrixCSC{Float64,Int64},SparseArrays.SparseMatrixCSC{UInt64,Int64}})(::Array{Float64,1}, ::Array{Float64,1}) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:147
#  [4] (::SpectralPOP.var"#13#15"{SpectralPOP.var"#Primitive1#33"{Array{Float64,2}},SpectralPOP.var"#Primitive2#34"{Bool,Int64,SparseArrays.SparseMatrixCSC{Float64,Int64},SparseArrays.SparseMatrixCSC{UInt64,Int64}}})(::Array{Float64,1}) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/solvers/SketchyCGAL/CGAL.jl:58
#  [5] #ApproxMinEvecLanczos#16(::String, ::Bool, ::typeof(SpectralPOP.ApproxMinEvecLanczos), ::SpectralPOP.var"#13#15"{SpectralPOP.var"#Primitive1#33"{Array{Float64,2}},SpectralPOP.var"#Primitive2#34"{Bool,Int64,SparseArrays.SparseMatrixCSC{Float64,Int64},SparseArrays.SparseMatrixCSC{UInt64,Int64}}}, ::UInt32, ::UInt64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/solvers/SketchyCGAL/CGAL.jl:139
#  [6] #ApproxMinEvecLanczos at ./none:0 [inlined]
#  [7] #CGAL#11(::Float64, ::String, ::Bool, ::typeof(SpectralPOP.CGAL), ::UInt32, ::SpectralPOP.var"#Primitive1#33"{Array{Float64,2}}, ::SpectralPOP.var"#Primitive2#34"{Bool,Int64,SparseArrays.SparseMatrixCSC{Float64,Int64},SparseArrays.SparseMatrixCSC{UInt64,Int64}}, ::SpectralPOP.var"#Primitive3#35"{Bool,Int64,SparseArrays.SparseMatrixCSC{Float64,Int64}}, ::Array{Float32,1}, ::Array{Float64,1}, ::UInt16, ::UInt64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/solvers/SketchyCGAL/CGAL.jl:58
#  [8] #CGAL at ./none:0 [inlined]
#  [9] #SpectralSDP#30(::String, ::String, ::Float64, ::Bool, ::Bool, ::typeof(SpectralPOP.SpectralSDP), ::Int64, ::Int64, ::Array{Float64,1}, ::SparseArrays.SparseMatrixCSC{Float64,Int64}, ::Array{UInt64,1}, ::Array{Float64,1}, ::SparseArrays.SparseMatrixCSC{UInt64,Int64}, ::Float64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:158
#  [10] #SpectralSDP at ./none:0 [inlined]
#  [11] macro expansion at ./util.jl:155 [inlined]
#  [12] macro expansion at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:59 [inlined]
#  [13] macro expansion at ./util.jl:155 [inlined]
#  [14] #CTP_POP#28(::String, ::String, ::Float64, ::Bool, ::Bool, ::typeof(CTP_POP), ::Array{PolyVar{true},1}, ::Polynomial{true,Float64}, ::Array{Polynomial{true,Float64},1}, ::Int64, ::Float64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:48
#  [15] #CTP_POP at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/test/poly_opt/test_random_dense_equality_constrained_QCQP_on_sphere_first_order.jl:0 [inlined]
#  [16] test(::Int64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/test/poly_opt/test_random_dense_equality_constrained_QCQP_on_sphere_first_order.jl:78
#  [17] top-level scope at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/test/poly_opt/test_random_dense_equality_constrained_QCQP_on_sphere_first_order.jl:92
#  [18] include at ./boot.jl:328 [inlined]
#  [19] include_relative(::Module, ::String) at ./loading.jl:1105
#  [20] include(::Module, ::String) at ./Base.jl:31
#  [21] include(::String) at ./client.jl:424
#  [22] top-level scope at In[10]:1

# %%
include("../test/poly_opt/test_random_dense_equality_constrained_QCQP_on_sphere_second_order.jl")
# Out:
# ***Problem setting***
# Number of variable: n=5
# ====================
# Number of equality constraints: l_h=3
# ====================
# Relaxed order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-1.4116459303475193
#   0.035870 seconds (82.95 k allocations: 9.002 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=21
#   Number of equality trace constraints: m=169
#   0.001821 seconds (15.23 k allocations: 1.759 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       169
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        262
# N. func. eval.:  402
# Final value:     1.411647
# Execution time:  0.162689
#   0.167723 seconds (106.10 k allocations: 13.123 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-1.4116469687080748
# ====================================
# Dimension of the null space of Gram matrix = 2
# ------------------------------------
# atom 1 = [0.15791372488608993, -0.2048748690152838, 0.40688882680597016, -0.6856559628703903, -0.5016106055273147]
#   check gap of lower bound  = 0.06519424462910806
#   check equality constraint 1 = 0.0457937271618305
#   check equality constraint 2 = 0.036867621589775634
#   check equality constraint 3 = 0.013664180069060006
# ####################################
# Optimal solution: opt_sol = [0.15791372488608993, -0.2048748690152838, 0.40688882680597016, -0.6856559628703903, -0.5016106055273147]
# ####################################
# ------------------------------------
# atom 2 = [-0.1607302845461082, -0.3464718437337013, 0.2219182341279034, -0.8535592548154822, -0.0072249530490230834]
#   check gap of lower bound  = 0.13329725656590896
#   check equality constraint 1 = 0.0762597330633279
#   check equality constraint 2 = 0.09252263435615316
#   check equality constraint 3 = 0.0761120115617997
#   0.078132 seconds (61.50 k allocations: 2.885 MiB)
#   0.248177 seconds (183.81 k allocations: 17.788 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=21
#   Number of equality trace constraints: m=169
#   0.001856 seconds (15.23 k allocations: 1.762 MiB)
# **SketchyCGAL solver:
# - SketchyCGAL SDP Solver - Beta.V.0.0
# --------------------------
#  iter=1
#  stopObj=5.078253476906283
#  stopFeas=1.0
#  primalObj=-0.6528441050504186
# --------------------------
#  iter=2
#  stopObj=103.52420248919103
#  stopFeas=7.003392706485834
#  primalObj=-0.30598324247155956
# --------------------------
#  iter=4
#  stopObj=30.97313707418866
#  stopFeas=2.235960837871403
#  primalObj=-0.5131015376993624
# --------------------------
#  iter=8
#  stopObj=6.584640456714628
#  stopFeas=1.0450566674409136
#  primalObj=-0.7585382918242825
# --------------------------
#  iter=16
#  stopObj=1.8796961287005889
#  stopFeas=0.34674219258122296
#  primalObj=-0.8762331593372927
# --------------------------
#  iter=32
#  stopObj=0.9777250456573849
#  stopFeas=0.1631277160221195
#  primalObj=-0.9852350901316724
# --------------------------
#  iter=64
#  stopObj=0.4560884301444328
#  stopFeas=0.06665404378787683
#  primalObj=-1.102923069307814
# --------------------------
#  iter=128
#  stopObj=0.5212640478971031
#  stopFeas=0.033693317632501336
#  primalObj=-1.2404918882366187
# --------------------------
#  iter=256
#  stopObj=0.12865902758425074
#  stopFeas=0.009798277797863351
#  primalObj=-1.3045252254648816
# --------------------------
#  iter=512
#  stopObj=-0.02406456100092802
#  stopFeas=0.0039203972720888375
#  primalObj=-1.345384324093384
# --------------------------
#  iter=1024
#  stopObj=0.06527896202302674
#  stopFeas=0.0027401161061664267
#  primalObj=-1.3787898482711722
# * status = stopping criteria met
#   0.633385 seconds (1.17 M allocations: 1001.747 MiB, 17.60% gc time)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-1.3957524445914078
# ====================================
# Rank of moment matrix = 21
#   0.000083 seconds (109 allocations: 26.453 KiB)
#   0.635978 seconds (1.19 M allocations: 1003.561 MiB, 17.53% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ***Problem setting***
# Number of variable: n=10
# ====================
# Number of equality constraints: l_h=4
# ====================
# Relaxed order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-1.2293443633775356
#   0.421048 seconds (829.32 k allocations: 91.276 MiB, 4.05% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=66
#   Number of equality trace constraints: m=1475
#   0.045289 seconds (235.60 k allocations: 33.110 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       1475
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     2
# N. iter.:        1275
# N. func. eval.:  3326
# Final value:     1.230698
# Execution time:  4.884995
#   4.922340 seconds (2.02 M allocations: 640.339 MiB, 1.32% gc time)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-1.2306975691621052
# ====================================
# Dimension of the null space of Gram matrix = 4
# ------------------------------------
# atom 1 = [-0.27454337556569913, 0.22816863910263654, -0.4662915130184043, -0.38377625976214835, -0.1687789500561475, -0.3251864979745754, -0.1372675867034316, 0.07154109672595238, -0.47150364562124547, 0.35086172727121717]
#   check gap of lower bound  = 0.025997853123140624
#   check equality constraint 1 = 0.004240263567998337
#   check equality constraint 2 = 0.017171127243079454
#   check equality constraint 3 = 0.009611383568942866
#   check equality constraint 4 = 0.00843570417154027
# ####################################
# Optimal solution: opt_sol = [-0.27454337556569913, 0.22816863910263654, -0.4662915130184043, -0.38377625976214835, -0.1687789500561475, -0.3251864979745754, -0.1372675867034316, 0.07154109672595238, -0.47150364562124547, 0.35086172727121717]
# ####################################
# ------------------------------------
# atom 2 = [0.803321379974988, -0.4982357614874153, 0.5333661152637312, 0.02118401734584368, 0.016242781672834383, 0.4209439856612076, 0.15853412381223309, 0.2897340976372326, 0.7498565686923293, -0.8019227108950967]
#   check gap of lower bound  = 1.252589857973351
#   check equality constraint 1 = 1.6703937796800599
#   check equality constraint 2 = 0.4590367787792512
#   check equality constraint 3 = 1.7517280457317894
#   check equality constraint 4 = 0.2566361697378038
# ------------------------------------
# atom 3 = [0.28957967984537225, 0.4352445739525944, 0.24578443826630098, -0.38335854841649813, -0.30249597682713064, -0.0866213761287561, -0.2805977883349035, 0.00867050528281378, -0.21849551307123863, 1.047064313361294]
#   check gap of lower bound  = 0.26180195942308937
#   check equality constraint 1 = 0.802569337698769
#   check equality constraint 2 = 0.05505640846425766
#   check equality constraint 3 = 0.3134150944600581
#   check equality constraint 4 = 0.20849851231814487
# ------------------------------------
# atom 4 = [-0.17284709784552316, -0.1910532229607354, 0.6311521284979332, 0.40492828259043323, -0.5186788888788103, 0.4380608774429716, -0.23744343847711374, -0.270460902823142, 0.05105106389026082, 0.9975703568034979]
#   check gap of lower bound  = 0.38479294846563805
#   check equality constraint 1 = 1.2169038130302066
#   check equality constraint 2 = 1.8755893493821143
#   check equality constraint 3 = 0.8463951814323051
#   check equality constraint 4 = 0.22602402290641987
#   0.203185 seconds (344.67 k allocations: 17.760 MiB)
#   5.171286 seconds (2.60 M allocations: 691.232 MiB, 1.26% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=66
#   Number of equality trace constraints: m=1475
#   0.072573 seconds (235.60 k allocations: 33.110 MiB, 24.52% gc time)
# **SketchyCGAL solver:
# - SketchyCGAL SDP Solver - Beta.V.0.0
# --------------------------
#  iter=1
#  stopObj=4.143014190327245
#  stopFeas=1.0
#  primalObj=-0.47653516620226877
# --------------------------
#  iter=2
#  stopObj=85.26544831952754
#  stopFeas=5.885376072405839
#  primalObj=-1.0904802990403857
# --------------------------
#  iter=4
#  stopObj=26.924199601902576
#  stopFeas=2.7163064515779096
#  primalObj=-0.43270021227548616
# --------------------------
#  iter=8
#  stopObj=19.42071639833225
#  stopFeas=1.4225195252921405
#  primalObj=-0.36527860461136863
# --------------------------
#  iter=16
#  stopObj=7.677337383551237
#  stopFeas=0.6757804878688743
#  primalObj=-0.19200011124069377
# --------------------------
#  iter=32
#  stopObj=3.4011153821215006
#  stopFeas=0.2566419131456959
#  primalObj=-0.4380362938543062
# --------------------------
#  iter=64
#  stopObj=2.631504829895881
#  stopFeas=0.1073336207998664
#  primalObj=-0.6461008108738415
# --------------------------
#  iter=128
#  stopObj=1.5902700305251098
#  stopFeas=0.047702211486121186
#  primalObj=-0.8053673857432575
# --------------------------
#  iter=256
#  stopObj=0.6402115252127323
#  stopFeas=0.020602590826269054
#  primalObj=-0.9539778074118757
# --------------------------
#  iter=512
#  stopObj=0.7222212377282604
#  stopFeas=0.009287777659151314
#  primalObj=-1.041073377817301
# --------------------------
#  iter=1024
#  stopObj=0.20749385484447247
#  stopFeas=0.00323970490293089
#  primalObj=-1.1130901635769614
# InterruptException:
#
# Stacktrace:
#  [1] * at ./boot.jl:404 [inlined]
#  [2] (::SpectralPOP.var"#Primitive2#34"{Bool,Int64,SparseArrays.SparseMatrixCSC{Float64,Int64},SparseArrays.SparseMatrixCSC{UInt64,Int64}})(::Array{Float64,1}, ::Array{Float64,1}) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:147
#  [3] (::SpectralPOP.var"#13#15"{SpectralPOP.var"#Primitive1#33"{Array{Float64,2}},SpectralPOP.var"#Primitive2#34"{Bool,Int64,SparseArrays.SparseMatrixCSC{Float64,Int64},SparseArrays.SparseMatrixCSC{UInt64,Int64}}})(::Array{Float64,1}) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/solvers/SketchyCGAL/CGAL.jl:58
#  [4] #ApproxMinEvecLanczos#16(::String, ::Bool, ::typeof(SpectralPOP.ApproxMinEvecLanczos), ::SpectralPOP.var"#13#15"{SpectralPOP.var"#Primitive1#33"{Array{Float64,2}},SpectralPOP.var"#Primitive2#34"{Bool,Int64,SparseArrays.SparseMatrixCSC{Float64,Int64},SparseArrays.SparseMatrixCSC{UInt64,Int64}}}, ::UInt32, ::UInt64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/solvers/SketchyCGAL/CGAL.jl:139
#  [5] #ApproxMinEvecLanczos at ./none:0 [inlined]
#  [6] #CGAL#11(::Float64, ::String, ::Bool, ::typeof(SpectralPOP.CGAL), ::UInt32, ::SpectralPOP.var"#Primitive1#33"{Array{Float64,2}}, ::SpectralPOP.var"#Primitive2#34"{Bool,Int64,SparseArrays.SparseMatrixCSC{Float64,Int64},SparseArrays.SparseMatrixCSC{UInt64,Int64}}, ::SpectralPOP.var"#Primitive3#35"{Bool,Int64,SparseArrays.SparseMatrixCSC{Float64,Int64}}, ::Array{Float32,1}, ::Array{Float64,1}, ::UInt16, ::UInt64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/solvers/SketchyCGAL/CGAL.jl:58
#  [7] #CGAL at ./none:0 [inlined]
#  [8] #SpectralSDP#30(::String, ::String, ::Float64, ::Bool, ::Bool, ::typeof(SpectralPOP.SpectralSDP), ::Int64, ::Int64, ::Array{Float64,1}, ::SparseArrays.SparseMatrixCSC{Float64,Int64}, ::Array{UInt64,1}, ::Array{Float64,1}, ::SparseArrays.SparseMatrixCSC{UInt64,Int64}, ::Float64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:158
#  [9] #SpectralSDP at ./none:0 [inlined]
#  [10] macro expansion at ./util.jl:155 [inlined]
#  [11] macro expansion at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:59 [inlined]
#  [12] macro expansion at ./util.jl:155 [inlined]
#  [13] #CTP_POP#28(::String, ::String, ::Float64, ::Bool, ::Bool, ::typeof(CTP_POP), ::Array{PolyVar{true},1}, ::Polynomial{true,Float64}, ::Array{Polynomial{true,Float64},1}, ::Int64, ::Float64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:48
#  [14] #CTP_POP at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/test/poly_opt/test_random_dense_equality_constrained_QCQP_on_sphere_second_order.jl:0 [inlined]
#  [15] test(::Int64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/test/poly_opt/test_random_dense_equality_constrained_QCQP_on_sphere_second_order.jl:78
#  [16] top-level scope at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/test/poly_opt/test_random_dense_equality_constrained_QCQP_on_sphere_second_order.jl:92
#  [17] include at ./boot.jl:328 [inlined]
#  [18] include_relative(::Module, ::String) at ./loading.jl:1105
#  [19] include(::Module, ::String) at ./Base.jl:31
#  [20] include(::String) at ./client.jl:424
#  [21] top-level scope at In[11]:1

# %%
include("../test/poly_opt/test_random_dense_QCQP_unique_inequality_(ball)_constraint.jl")
# Out:
# ***Problem setting***
# Number of variable: n=5
# ====================
# Number of inequality constraints: l_g=1
# ====================
# Number of equality constraints: l_h=2
# ====================
# Relaxed order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-1.5302641178581289
#   0.233688 seconds (228.39 k allocations: 16.399 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=28
#   Number of equality trace constraints: m=281
#   0.003000 seconds (23.74 k allocations: 2.733 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       281
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        19
# N. func. eval.:  20
# Final value:     1.530265
# Execution time:  0.010452
#   0.011399 seconds (6.90 k allocations: 1009.891 KiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-1.5302645425584074
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [0.3581764511927796, -0.8089208130337529, -0.361299077005231, -0.20474158965679942, -0.21124721912384178, 2.21796528984982e-17]
#   check gap of lower bound  = 0.00047261894459049714
#   check equality constraint 1 = 0.00023641160639246983
#   check equality constraint 2 = 0.0005652838788415548
#   check equality constraint 3 = 0.0002752188841771419
# ####################################
# Optimal solution: opt_sol = [0.3581764511927796, -0.8089208130337529, -0.361299077005231, -0.20474158965679942, -0.21124721912384178, 2.21796528984982e-17]
# ####################################
#   0.001608 seconds (2.25 k allocations: 146.109 KiB)
#   0.016504 seconds (33.95 k allocations: 3.884 MiB)
#   0.160710 seconds (160.80 k allocations: 10.099 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#   Largest upper bound of psd matrix: bound_ak=57.0
#   Number of blocks: numBloc=3
#   Size of block-diagonal matrix: s=28
#   Size of blocks: [21, 6, 1]
#   Number of equality trace constraints: m=169
#   0.335578 seconds (430.96 k allocations: 24.129 MiB)
# ***LMBM solver:***
# ---------------
# | Parameters: |
# ---------------
# n:       169
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     3
# N. iter.:        528
# N. func. eval.:  1396
# Final value:     1.552633
# Execution time:  1.366928
# ####################################
# opt_val = -1.5526331525897852
# ####################################
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [0.7237646557685122, -1.1171339506312328, -0.4431574498890685, -0.2311990928709422, -0.1729810912625408]
#   check gap of lower bound  = -1.267275694814341
#   check inequality constraint 1 = -1.0515875444635667
#   check equality constraint 1 = -0.09246736958223063
#   check equality constraint 2 = 0.357209079641367
#   1.944581 seconds (2.26 M allocations: 218.088 MiB, 3.19% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ***Problem setting***
# Number of variable: n=10
# ====================
# Number of inequality constraints: l_g=1
# ====================
# Number of equality constraints: l_h=3
# ====================
# Relaxed order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-2.540454866700168
#   0.472779 seconds (854.03 k allocations: 93.761 MiB, 5.16% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=78
#   Number of equality trace constraints: m=2029
#   0.056334 seconds (301.62 k allocations: 46.644 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       2029
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        23
# N. func. eval.:  28
# Final value:     2.540457
# Execution time:  0.025589
#   0.026313 seconds (13.25 k allocations: 6.660 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-2.5404565353470194
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [-0.00985757673410113, 0.45397530070459824, 0.14137316584120316, -0.20748432430851396, 0.2750372320838906, 0.6771471665750765, 0.034785977671581925, -0.12874258782952616, -0.4095753621194814, -0.10446968013814158, 0.0]
#   check gap of lower bound  = 0.00033972565996487347
#   check equality constraint 1 = 0.00014691548235103158
#   check equality constraint 2 = 0.0006309705874945615
#   check equality constraint 3 = 0.0005715288515396877
#   check equality constraint 4 = 0.00014876395727270175
# ####################################
# Optimal solution: opt_sol = [-0.00985757673410113, 0.45397530070459824, 0.14137316584120316, -0.20748432430851396, 0.2750372320838906, 0.6771471665750765, 0.034785977671581925, -0.12874258782952616, -0.4095753621194814, -0.10446968013814158, 0.0]
# ####################################
#   0.004356 seconds (3.41 k allocations: 658.047 KiB)
#   0.087475 seconds (319.25 k allocations: 53.968 MiB)
#   0.087777 seconds (320.52 k allocations: 54.033 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#   Largest upper bound of psd matrix: bound_ak=187.0
#   Number of blocks: numBloc=3
#   Size of block-diagonal matrix: s=78
#   Size of blocks: [66, 11, 1]
#   Number of equality trace constraints: m=1475
#   0.319604 seconds (300.77 k allocations: 117.208 MiB, 11.20% gc time)
# ***LMBM solver:***
# ---------------
# | Parameters: |
# ---------------
# n:       1475
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# InterruptException:
#
# Stacktrace:
#  [1] _At_or_Ac_mul_B(::Function, ::SparseArrays.SparseMatrixCSC{Float64,Int64}, ::SparseArrays.SparseVector{Float64,Int64}) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SparseArrays/src/sparsevector.jl:1752
#  [2] * at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SparseArrays/src/sparsevector.jl:1731 [inlined]
#  [3] (::SpectralPOP.var"#phi#75"{Bool,Int64,UInt64,SparseArrays.SparseMatrixCSC{UInt64,Int64},Array{Array{UInt64,1},1},Float16,SparseArrays.SparseMatrixCSC{Float64,Int64},Array{Float64,1},SpectralPOP.var"#my_eigs#74"{String,Int64,Int64,Array{Int64,1},Int64,Int64}})(::Int32, ::Ptr{Float64}, ::Ptr{Float64}) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_BTP.jl:374
#  [4] #lmbm#1(::Int64, ::Int64, ::Bool, ::Float64, ::Float64, ::typeof(SpectralPOP.lmbm), ::Function, ::Array{Float64,1}) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/solvers/LMBM/LMBM.jl:106
#  [5] #lmbm at ./none:0 [inlined]
#  [6] macro expansion at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_BTP.jl:383 [inlined]
#  [7] macro expansion at ./util.jl:155 [inlined]
#  [8] #BTP_POP#52(::Float64, ::String, ::Float64, ::Bool, ::typeof(SpectralPOP.BTP_POP), ::Array{PolyVar{true},1}, ::Polynomial{true,Float64}, ::Array{Polynomial{true,Float64},1}, ::Array{Polynomial{true,Float64},1}, ::Int64, ::Float64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_BTP.jl:83
#  [9] BTP_POP(::Array{PolyVar{true},1}, ::Polynomial{true,Float64}, ::Array{Polynomial{true,Float64},1}, ::Array{Polynomial{true,Float64},1}, ::Int64, ::Float64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_BTP.jl:83
#  [10] test(::Int64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/test/poly_opt/test_random_dense_QCQP_unique_inequality_(ball)_constraint.jl:80
#  [11] top-level scope at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/test/poly_opt/test_random_dense_QCQP_unique_inequality_(ball)_constraint.jl:94
#  [12] include at ./boot.jl:328 [inlined]
#  [13] include_relative(::Module, ::String) at ./loading.jl:1105
#  [14] include(::Module, ::String) at ./Base.jl:31
#  [15] include(::String) at ./client.jl:424
#  [16] top-level scope at In[12]:1

# %%
include("../test/poly_opt/test_random_dense_QCQP_on_ball.jl")
# Out:
# ***Problem setting***
# Number of variable: n=10
# ====================
# Number of inequality constraints: l_g=2
# ====================
# Number of equality constraints: l_h=2
# ====================
# Relaxed order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-1.489897671545476
#   0.620978 seconds (876.64 k allocations: 95.830 MiB, 4.59% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Conpute upper bound 1
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=78
#   Number of equality trace constraints: m=1951
#   0.044323 seconds (228.44 k allocations: 35.119 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       1951
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     2
# N. iter.:        193
# N. func. eval.:  359
# Final value:     0.894088
# Execution time:  0.457489
#   0.468884 seconds (194.79 k allocations: 81.455 MiB, 5.52% gc time)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-0.89408839807347
# ====================================
# Dimension of the null space of Gram matrix = 2
# ------------------------------------
# atom 1 = [0.08537680939591966, 0.10298475643512586, 0.07006458913627103, -0.07280463321678038, 0.049977819695854686, 0.0868490728992596, 0.06874395045957099, -0.1966105587030144, 0.0770655889704615, 0.1358592585757018, -0.9455203252110889]
#   check gap of lower bound  = 1.1848570178996098e-5
#   check equality constraint 1 = 2.5918159250459816e-5
#   check equality constraint 2 = 1.1288550094259997e-5
#   check equality constraint 3 = 6.78641160076765e-5
# ####################################
# Optimal solution: opt_sol = [0.08537680939591966, 0.10298475643512586, 0.07006458913627103, -0.07280463321678038, 0.049977819695854686, 0.0868490728992596, 0.06874395045957099, -0.1966105587030144, 0.0770655889704615, 0.1358592585757018, -0.9455203252110889]
# ####################################
# ------------------------------------
# atom 2 = [0.08537931593854055, 0.10297345226523422, 0.0700735709474408, -0.07281550350440519, 0.049978212429328366, 0.08684156484409827, 0.06871727978962458, -0.1965630360766143, 0.07707114645111932, 0.13585943356069807, 0.9456117446629986]
#   check gap of lower bound  = 9.921470782048303e-6
#   check equality constraint 1 = 3.0224501118003566e-5
#   check equality constraint 2 = 9.199390905184623e-6
#   check equality constraint 3 = 8.32521003479858e-5
# ####################################
# Optimal solution: opt_sol = [0.08537931593854055, 0.10297345226523422, 0.0700735709474408, -0.07281550350440519, 0.049978212429328366, 0.08684156484409827, 0.06871727978962458, -0.1965630360766143, 0.07707114645111932, 0.13585943356069807, 0.9456117446629986]
# ####################################
#   0.006368 seconds (6.95 k allocations: 873.094 KiB)
#   0.520071 seconds (431.20 k allocations: 117.447 MiB, 4.97% gc time)
# --------------------------
# **Conpute upper bound 2
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=78
#   Number of equality trace constraints: m=1951
#   0.063281 seconds (229.07 k allocations: 35.221 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       1951
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        42
# N. func. eval.:  53
# Final value:     2.527995
# Execution time:  0.162628
#   0.074708 seconds (25.30 k allocations: 12.214 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-2.527994823912173
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [0.09483823039833005, -0.374555445841761, -0.47267088489112885, -0.2801456369186609, 0.43824578793826496, 0.13589870927996628, -0.3199590729398771, -0.4607747410483183, -0.13621509410045116, 0.04965326981047597, 0.0]
#   check gap of lower bound  = 0.005414791398632435
#   check equality constraint 1 = 0.00044800676936751493
#   check equality constraint 2 = 7.903338471049182e-5
#   check equality constraint 3 = 0.0025795854989193456
# ####################################
# Optimal solution: opt_sol = [0.09483823039833005, -0.374555445841761, -0.47267088489112885, -0.2801456369186609, 0.43824578793826496, 0.13589870927996628, -0.3199590729398771, -0.4607747410483183, -0.13621509410045116, 0.04965326981047597, 0.0]
# ####################################
#   0.004656 seconds (3.26 k allocations: 655.625 KiB)
#   0.143179 seconds (258.62 k allocations: 48.096 MiB)
# --------------------------
#   Radius of big ball: R_bar=4.422083221985643
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=105
#   Number of equality trace constraints: m=3711
#   0.122301 seconds (486.67 k allocations: 81.109 MiB, 17.47% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       3711
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# InterruptException:
#
# Stacktrace:
#  [1] aupd_wrapper(::Type, ::Arpack.var"#matvecA!#24"{Array{Float64,2}}, ::Arpack.var"#18#25", ::Arpack.var"#19#26", ::Int64, ::Bool, ::Bool, ::String, ::Int64, ::Int64, ::String, ::Float64, ::Int64, ::Int64, ::Array{Float64,1}) at /home/hoanganh/.julia/packages/Arpack/o35I5/src/libarpack.jl:79
#  [2] #_eigs#17(::Int64, ::Int64, ::Symbol, ::Float64, ::Int64, ::Nothing, ::Array{Float64,1}, ::Bool, ::typeof(Arpack._eigs), ::Array{Float64,2}, ::LinearAlgebra.UniformScaling{Bool}) at /home/hoanganh/.julia/packages/Arpack/o35I5/src/Arpack.jl:181
#  [3] #_eigs at ./none:0 [inlined]
#  [4] #eigs#10 at /home/hoanganh/.julia/packages/Arpack/o35I5/src/Arpack.jl:46 [inlined]
#  [5] #eigs at ./none:0 [inlined]
#  [6] #eigs#9 at /home/hoanganh/.julia/packages/Arpack/o35I5/src/Arpack.jl:45 [inlined]
#  [7] #eigs at ./none:0 [inlined]
#  [8] #LargEig#42(::String, ::Bool, ::typeof(SpectralPOP.LargEig), ::Array{Float64,2}, ::Int64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:199
#  [9] #LargEig at ./none:0 [inlined]
#  [10] (::SpectralPOP.var"#phi#31"{String,Bool,Bool,Int64,Array{Float64,1},SparseArrays.SparseMatrixCSC{Float64,Int64},Array{UInt64,1},Array{Float64,1},SparseArrays.SparseMatrixCSC{UInt64,Int64},Float64})(::Int32, ::Ptr{Float64}, ::Ptr{Float64}) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:115
#  [11] #lmbm#1(::Int64, ::Int64, ::Bool, ::Float64, ::Float64, ::typeof(SpectralPOP.lmbm), ::Function, ::Array{Float64,1}) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/solvers/LMBM/LMBM.jl:106
#  [12] #lmbm at ./none:0 [inlined]
#  [13] #SpectralSDP#30(::String, ::String, ::Float64, ::Bool, ::Bool, ::typeof(SpectralPOP.SpectralSDP), ::Int64, ::Int64, ::Array{Float64,1}, ::SparseArrays.SparseMatrixCSC{Float64,Int64}, ::Array{UInt64,1}, ::Array{Float64,1}, ::SparseArrays.SparseMatrixCSC{UInt64,Int64}, ::Float64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:124
#  [14] #SpectralSDP at ./none:0 [inlined]
#  [15] macro expansion at ./util.jl:155 [inlined]
#  [16] macro expansion at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:59 [inlined]
#  [17] macro expansion at ./util.jl:155 [inlined]
#  [18] #CTP_POP#28(::String, ::String, ::Float64, ::Bool, ::Bool, ::typeof(CTP_POP), ::Array{PolyVar{true},1}, ::Polynomial{true,Float64}, ::Array{Polynomial{true,Float64},1}, ::Int64, ::Float64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:48
#  [19] #CTP_POP at ./none:0 [inlined]
#  [20] macro expansion at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:21 [inlined]
#  [21] macro expansion at ./util.jl:155 [inlined]
#  [22] #CTP_POP_on_Ball#24(::String, ::String, ::Float64, ::Bool, ::typeof(SpectralPOP.CTP_POP_on_Ball), ::Array{PolyVar{true},1}, ::Polynomial{true,Float64}, ::Array{Polynomial{true,Float64},1}, ::Array{Polynomial{true,Float64},1}, ::Int64, ::Float64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:2
#  [23] CTP_POP_on_Ball(::Array{PolyVar{true},1}, ::Polynomial{true,Float64}, ::Array{Polynomial{true,Float64},1}, ::Array{Polynomial{true,Float64},1}, ::Int64, ::Float64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:2
#  [24] test(::Int64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/test/poly_opt/test_random_dense_QCQP_on_ball.jl:87
#  [25] top-level scope at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/test/poly_opt/test_random_dense_QCQP_on_ball.jl:108
#  [26] include at ./boot.jl:328 [inlined]
#  [27] include_relative(::Module, ::String) at ./loading.jl:1105
#  [28] include(::Module, ::String) at ./Base.jl:31
#  [29] include(::String) at ./client.jl:424
#  [30] top-level scope at In[13]:1

# %%
include("../test/poly_opt/test_random_dense_quartics_on_sphere.jl")

# %%
include("../test/poly_opt/Evaluation_comparisons.jl")

# %%
include("../test/poly_opt/Norm_Subgrad.jl")
