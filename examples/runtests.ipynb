# %%
println("****Test polynomial optimization****")

using DynamicPolynomials

@polyvar x[1:2] # variables

f=x[1]^2+0.5*x[1]*x[2]-0.25*x[2]^2+0.75*x[1]-0.3*x[2] # objective function

R=1.0 # squared radius of a sphere constraint
h=[R-sum(x.^2);(x[1]-1.0)*x[2]] # equality constraints (including the sphere constraint)

k=2 # relaxed order

include("../src/SpectralPOP.jl")
using .SpectralPOP

g=Vector{Polynomial{true,Float64}}([])
opt_val = SpectralPOP.SumofSquares_POP_WithExtraction(x,f,g,h,k) # SumOfSquares.jl + Mosek
println()
println(".................................")
println()


# get approximations of the optimal value and an optimal solution
opt_val,opt_sol = SpectralPOP.CTP_POP(x,f,h,k,R,method="LMBM",EigAlg="Arpack",tol=1e-5)# Limited Memory Bundle Method
println()
println(".................................")
println()
opt_val,opt_sol = SpectralPOP.CTP_POP(x,f,h,k,R,method="SketchyCGAL",EigAlg="Normal",tol=1e-3)# Limited Memory Bundle Method
# Out:
# ****Test polynomial optimization****
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=0.2499999989810142
# Atomic measure on the variables x[1], x[2] with 1 atoms:
#  at [-1.000000003373059, 0.0] with weight 0.9999999960287472
#   0.015505 seconds (10.15 k allocations: 1.167 MiB)
#
# .................................
# WARNING: replacing module SpectralPOP.
# WARNING: using SpectralPOP.CTP_POP in module Main conflicts with an existing identifier.
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=6
#   Number of equality trace constraints: m=19
#   0.074459 seconds (51.50 k allocations: 2.595 MiB, 32.39% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       19
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        18
# N. func. eval.:  21
# Final value:     -0.250000
# Execution time:  0.061455
#   0.210438 seconds (255.50 k allocations: 14.494 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=0.24999969546589917
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [-0.9999869163168831, -9.516753087602626e-5]
#   check gap of lower bound  = 6.008123930251186e-5
#   check equality constraint 1 = 2.615813819217827e-5
#   check equality constraint 2 = 0.00019033381661023554
# ####################################
# Optimal solution: opt_sol = [-0.9999869163168831, -9.516753087602626e-5]
# ####################################
#   0.000589 seconds (1.28 k allocations: 42.375 KiB)
#   0.285925 seconds (309.33 k allocations: 17.152 MiB, 8.44% gc time)
#
# .................................
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=6
#   Number of equality trace constraints: m=19
#   0.000236 seconds (1.00 k allocations: 74.156 KiB)
# **SketchyCGAL solver:
# - SketchyCGAL SDP Solver - Beta.V.0.0
# --------------------------
#  iter=1
#  stopObj=4.105237911414446
#  stopFeas=1.0
#  primalObj=-0.3411397300361804
# --------------------------
#  iter=2
#  stopObj=36.90582310320491
#  stopFeas=3.964197172243201
#  primalObj=-0.37305019591401667
# --------------------------
#  iter=4
#  stopObj=11.872481902069305
#  stopFeas=1.6719649046596226
#  primalObj=0.667863624651389
# --------------------------
#  iter=8
#  stopObj=5.348647898985477
#  stopFeas=0.5944692238281051
#  primalObj=0.5720693116527036
# --------------------------
#  iter=16
#  stopObj=3.4373207067569282
#  stopFeas=0.34023229521656495
#  primalObj=0.7040377013327512
# --------------------------
#  iter=32
#  stopObj=1.0267224166767395
#  stopFeas=0.11512634253892096
#  primalObj=0.5740729747964621
# --------------------------
#  iter=64
#  stopObj=1.4046217146602071
#  stopFeas=0.07349886276824225
#  primalObj=0.6349719291302531
# --------------------------
#  iter=128
#  stopObj=1.1576436238906984
#  stopFeas=0.03848257072944923
#  primalObj=0.6191837044814221
# --------------------------
#  iter=256
#  stopObj=0.40963848927117086
#  stopFeas=0.011725683686799345
#  primalObj=0.5040595531988482
# --------------------------
#  iter=512
#  stopObj=0.21765030266066765
#  stopFeas=0.005627792167914748
#  primalObj=0.4477951384138537
# --------------------------
#  iter=1024
#  stopObj=0.16269165154355514
#  stopFeas=0.0035765442722206467
#  primalObj=0.40750735821589096
# --------------------------
#  iter=2048
#  stopObj=0.4117456518850998
#  stopFeas=0.005158604566028941
#  primalObj=0.42603242386941953
# --------------------------
#  iter=4096
#  stopObj=0.35742590599030993
#  stopFeas=0.002599069281356836
#  primalObj=0.4730657071132532
# --------------------------
#  iter=8192
#  stopObj=0.2642545904525816
#  stopFeas=0.0017564962789491318
#  primalObj=0.5021624659805618
# * status = stopping criteria met
#   0.845836 seconds (4.73 M allocations: 554.629 MiB, 11.69% gc time)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=0.5414812205850467
# ====================================
# Rank of moment matrix = 6
#   0.145615 seconds (335.81 k allocations: 16.967 MiB)
#   0.992359 seconds (5.07 M allocations: 571.701 MiB, 9.96% gc time)
# (0.5414812205850467, Array{Float64,1}[])

# %%
println("****Test polynomial system****")

using DynamicPolynomials

@polyvar x[1:2] # variables

# mickey equations
h=[x[1]^2 + 4*x[2]^2 - 4;
        2*x[2]^2 - x[1]]

L=10 # squared radius of a ball centered at origin containing at least one real root
k=1 # relaxed order

include("../src/SpectralPOP.jl")
using .SpectralPOP

# get a real root
root = SpectralPOP.ASC_PolySys(x,h,k,L,method="LMBM",EigAlg="Arpack",tol=1e-5)
# Out:
# ****Test polynomial system****
# ------------------------------------
# Determine omega1:
# WARNING: replacing module SpectralPOP.
# WARNING: using SpectralPOP.CTP_POP in module Main conflicts with an existing identifier.
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=4
#   0.049962 seconds (51.25 k allocations: 2.571 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       4
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     3
# N. iter.:        244
# N. func. eval.:  2092
# Final value:     -1.218241
# Execution time:  0.166794
#   0.323210 seconds (468.61 k allocations: 25.995 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=1.218240666866828
# ====================================
# Dimension of the null space of Gram matrix = 3
#   0.000164 seconds (180 allocations: 13.938 KiB)
#   0.380661 seconds (521.67 k allocations: 28.640 MiB)
# omega1 = 1.218240666866828
# ------------------------------------
# ------------------------------------
# Determine omega2:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=5
#   0.000465 seconds (940 allocations: 67.484 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       5
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     3
# N. iter.:        59
# N. func. eval.:  206
# Final value:     -1.502764
# Execution time:  0.009544
#   0.014243 seconds (22.91 k allocations: 1.192 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=1.5027641555169873
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [0.39196922461675693, 0.2497251484950383, 0.0]
#   check gap of lower bound  = 0.7862119296695333
#   check equality constraint 1 = 0.7839974771624694
#   check equality constraint 2 = 0.0030904722101374182
#   check equality constraint 3 = 0.0007737473338286782
#   check equality constraint 4 = 0.7861765932628113
#   0.000721 seconds (1.12 k allocations: 37.531 KiB)
#   0.015888 seconds (25.96 k allocations: 1.315 MiB)
# omega2 = 1.5027641555169873
# ------------------------------------
# ------------------------------------
# Determine omega3:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=6
#   0.000243 seconds (826 allocations: 58.844 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       6
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        8
# N. func. eval.:  8
# Final value:     -0.227539
# Execution time:  0.000587
#   0.001243 seconds (2.53 k allocations: 84.078 KiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=0.22753890343624888
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [0.3908347449078756, 0.2485901169315699, 0.8862422260914993]
#   check gap of lower bound  = 4.922824837555462e-5
#   check equality constraint 1 = 2.5872629128120828e-5
#   check equality constraint 2 = 6.0017228589337446e-5
#   check equality constraint 3 = 1.294208124988372e-6
#   check equality constraint 4 = 6.397068829266939e-5
#   check equality constraint 5 = 2.9737990744793663e-5
# ####################################
# Optimal solution: opt_sol = [0.3908347449078756, 0.2485901169315699, 0.8862422260914993]
# ####################################
#   0.000866 seconds (1.72 k allocations: 49.578 KiB)
#   0.002766 seconds (6.07 k allocations: 216.609 KiB)
# omega3 = 0.22753890343624888
# ------------------------------------
# ------
#   0.896065 seconds (970.62 k allocations: 50.980 MiB)
#   1.323091 seconds (1.31 M allocations: 68.346 MiB, 2.91% gc time)
# 2-element Array{Float64,1}:
#  1.2359279826397824
#  0.7861109733113487

# %%
include("../test/runtests.jl")
# Out:
# ****Test polynomial optimization****
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=0.2499999989810142
# Atomic measure on the variables x[1], x[2] with 1 atoms:
#  at [-1.000000003373059, 0.0] with weight 0.9999999960287472
#   0.086313 seconds (10.28 k allocations: 1.173 MiB)
#
# .................................
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=6
#   Number of equality trace constraints: m=19
#   0.000761 seconds (1.00 k allocations: 74.156 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       19
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        18
# N. func. eval.:  21
# Final value:     -0.250000
# Execution time:  0.004837
#   0.006824 seconds (4.19 k allocations: 201.234 KiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=0.249999695465899
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [-0.9999869163168935, -9.516753084718495e-5]
#   check gap of lower bound  = 6.008123929257536e-5
#   check equality constraint 1 = 2.6158138171306078e-5
#   check equality constraint 2 = 0.00019033381655255427
# ####################################
# Optimal solution: opt_sol = [-0.9999869163168935, -9.516753084718495e-5]
# ####################################
#   0.002523 seconds (1.28 k allocations: 41.219 KiB)
#   0.011404 seconds (7.48 k allocations: 340.313 KiB)
#
# .................................
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=6
#   Number of equality trace constraints: m=19
#   0.001055 seconds (1.00 k allocations: 74.156 KiB)
# **SketchyCGAL solver:
# - SketchyCGAL SDP Solver - Beta.V.0.0
# --------------------------
#  iter=1
#  stopObj=-0.5375973927596969
#  stopFeas=1.0
#  primalObj=-0.16681999379156556
# --------------------------
#  iter=2
#  stopObj=27.335741187357762
#  stopFeas=4.1642695448154905
#  primalObj=0.3193759688009163
# --------------------------
#  iter=4
#  stopObj=13.83542853249082
#  stopFeas=1.5801683044877592
#  primalObj=0.36704248704960474
# --------------------------
#  iter=8
#  stopObj=4.587205744598435
#  stopFeas=0.8083358268377576
#  primalObj=0.39819207144392216
# --------------------------
#  iter=16
#  stopObj=-0.462324319321209
#  stopFeas=0.2691352622615605
#  primalObj=0.5883445740109099
# --------------------------
#  iter=32
#  stopObj=1.672964223285606
#  stopFeas=0.1668939797261871
#  primalObj=0.6420622623093526
# --------------------------
#  iter=64
#  stopObj=1.416096223612676
#  stopFeas=0.06697215969274167
#  primalObj=0.634534805392965
# --------------------------
#  iter=128
#  stopObj=0.8238301227192875
#  stopFeas=0.02908808039454628
#  primalObj=0.5913601106684707
# --------------------------
#  iter=256
#  stopObj=0.21566561383177235
#  stopFeas=0.011067240474375366
#  primalObj=0.49171393186121515
# --------------------------
#  iter=512
#  stopObj=0.23649102133493938
#  stopFeas=0.006871367060741839
#  primalObj=0.4527879467077253
# --------------------------
#  iter=1024
#  stopObj=0.21906209339409394
#  stopFeas=0.0038965995892998417
#  primalObj=0.44368368045397194
# --------------------------
#  iter=2048
#  stopObj=0.22456476960790867
#  stopFeas=0.0025074281092006614
#  primalObj=0.4452963993869207
# --------------------------
#  iter=4096
#  stopObj=-0.027411110597759164
#  stopFeas=0.002420156311317734
#  primalObj=0.4708630635786702
# --------------------------
#  iter=8192
#  stopObj=0.22562873975988806
#  stopFeas=0.001590038812258526
#  primalObj=0.5050086398810923
# * status = stopping criteria met
#   0.746127 seconds (4.63 M allocations: 552.194 MiB, 12.49% gc time)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=0.5478363622257019
# ====================================
# Rank of moment matrix = 6
#   0.000070 seconds (113 allocations: 7.250 KiB)
#   0.748078 seconds (4.64 M allocations: 552.297 MiB, 12.46% gc time)
#
#
#
#
#
# ****Test polynomial system****
# ------------------------------------
# Determine omega1:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=4
#   0.000173 seconds (752 allocations: 50.906 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       4
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     3
# N. iter.:        108
# N. func. eval.:  498
# Final value:     -1.218242
# Execution time:  0.024948
#   0.025705 seconds (52.97 k allocations: 2.811 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=1.2182419425285538
# ====================================
# Dimension of the null space of Gram matrix = 3
#   0.000148 seconds (178 allocations: 13.047 KiB)
#   0.026416 seconds (54.88 k allocations: 2.895 MiB)
# omega1 = 1.2182419425285538
# ------------------------------------
# ------------------------------------
# Determine omega2:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=5
#   0.000201 seconds (790 allocations: 57.688 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       5
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        56
# N. func. eval.:  159
# Final value:     -1.502791
# Execution time:  0.007736
#   0.008374 seconds (18.07 k allocations: 949.844 KiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=1.5027910823328325
# ====================================
# Dimension of the null space of Gram matrix = 2
#   0.000117 seconds (173 allocations: 12.313 KiB)
#   0.009066 seconds (20.03 k allocations: 1.017 MiB)
# omega2 = 1.5027910823328325
# ------------------------------------
# ------------------------------------
# Determine omega3:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=6
#   0.000170 seconds (825 allocations: 58.516 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       6
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        8
# N. func. eval.:  8
# Final value:     -0.227533
# Execution time:  0.000000
#   0.001126 seconds (2.56 k allocations: 85.000 KiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=0.227533187890094
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [0.39083477684294265, 0.24858457680361992, 0.8862475989380955]
#   check gap of lower bound  = 4.746452823808922e-5
#   check equality constraint 1 = 1.907876195317293e-5
#   check equality constraint 2 = 7.100991158792702e-5
#   check equality constraint 3 = 4.2247134634937344e-6
#   check equality constraint 4 = 6.942502360773872e-5
#   check equality constraint 5 = 2.0685297974498695e-5
# ####################################
# Optimal solution: opt_sol = [0.39083477684294265, 0.24858457680361992, 0.8862475989380955]
# ####################################
#   0.000719 seconds (1.72 k allocations: 49.578 KiB)
#   0.002389 seconds (6.12 k allocations: 217.266 KiB)
# omega3 = 0.227533187890094
# ------------------------------------
# ------
#   0.038752 seconds (83.84 k allocations: 4.255 MiB)
#   0.038961 seconds (84.70 k allocations: 4.294 MiB)
# 2-element Array{Float64,1}:
#  1.2359280836273314
#  0.786093453888498

# %%
include("../test/poly_opt/test_random_dense_quadratic_on_sphere.jl")
# Out:
# ***Problem setting***
# Number of variable: n=50
# ====================
# Number of equality constraints: l=1
# ====================
# Relaxed order: k=1
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-6.60542697587531
#   4.474234 seconds (7.61 M allocations: 423.882 MiB, 3.94% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=51
#   Number of equality trace constraints: m=2
#   0.024692 seconds (63.91 k allocations: 24.812 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       2
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        6
# N. func. eval.:  6
# Final value:     6.605427
# Execution time:  0.004631
#   0.005393 seconds (4.00 k allocations: 656.297 KiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-6.605427296010449
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [-0.06646904264604234, -0.05655227003331805, -0.0163009348605513, 0.005640016382042391, -0.01737524357390843, 0.07163535231644713, 0.019401703450168395, -0.06368302737192708, 0.27728669549050994, -0.17113616856626948, -0.1543391661722452, -0.24582067388441464, 0.004818906764209033, -0.10123849118053739, 0.1998538987659188, 0.2610020406838614, -0.2707244360094229, 0.14101968558202585, -0.05655038609623697, 0.13261619047775702, -0.0682632111521735, -0.025140971897349342, 0.03623622135568288, 0.17386070367840362, 0.02738997916632631, -0.15913633375488626, -0.023285717750473684, -0.12047244808918296, 0.2638135726696337, -0.20676907857920543, 0.23033820494311696, 0.04653798560576039, 0.11835259073030843, -0.10404021795831665, -0.04272113819505636, -0.07004333662442971, 0.09824258145824256, 0.19199331524197039, -0.17848924572891992, -0.25100051711529986, -0.08625161688064717, -0.04044961114137398, -0.0498426139618018, -0.061260382477424165, 0.11947812094453511, 0.09505484218328943, -0.29107748115892174, 0.11939414620619362, -0.06923717366643861, -0.0036221353215982067]
#   check gap of lower bound  = 0.006373517391494943
#   check equality constraint 1 = 0.0013846625311519922
# ####################################
# Optimal solution: opt_sol = [-0.06646904264604234, -0.05655227003331805, -0.0163009348605513, 0.005640016382042391, -0.01737524357390843, 0.07163535231644713, 0.019401703450168395, -0.06368302737192708, 0.27728669549050994, -0.17113616856626948, -0.1543391661722452, -0.24582067388441464, 0.004818906764209033, -0.10123849118053739, 0.1998538987659188, 0.2610020406838614, -0.2707244360094229, 0.14101968558202585, -0.05655038609623697, 0.13261619047775702, -0.0682632111521735, -0.025140971897349342, 0.03623622135568288, 0.17386070367840362, 0.02738997916632631, -0.15913633375488626, -0.023285717750473684, -0.12047244808918296, 0.2638135726696337, -0.20676907857920543, 0.23033820494311696, 0.04653798560576039, 0.11835259073030843, -0.10404021795831665, -0.04272113819505636, -0.07004333662442971, 0.09824258145824256, 0.19199331524197039, -0.17848924572891992, -0.25100051711529986, -0.08625161688064717, -0.04044961114137398, -0.0498426139618018, -0.061260382477424165, 0.11947812094453511, 0.09505484218328943, -0.29107748115892174, 0.11939414620619362, -0.06923717366643861, -0.0036221353215982067]
# ####################################
#   0.007648 seconds (11.13 k allocations: 1.132 MiB)
#   0.038211 seconds (80.04 k allocations: 26.607 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=51
#   Number of equality trace constraints: m=2
#   0.074124 seconds (63.91 k allocations: 24.812 MiB, 55.63% gc time)
# **SketchyCGAL solver:
# - SketchyCGAL SDP Solver - Beta.V.0.0
# --------------------------
#  iter=1
#  stopObj=5.250131028351141
#  stopFeas=1.0
#  primalObj=-5.857752972200054
# PosDefException: matrix is not positive definite; Cholesky factorization failed.
#
# Stacktrace:
#  [1] checkpositivedefinite at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/factorization.jl:18 [inlined]
#  [2] #cholesky!#124(::Bool, ::typeof(LinearAlgebra.cholesky!), ::LinearAlgebra.Hermitian{Float64,Array{Float64,2}}, ::Val{false}) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/cholesky.jl:226
#  [3] #cholesky! at ./none:0 [inlined]
#  [4] #cholesky!#125(::Bool, ::typeof(LinearAlgebra.cholesky!), ::Array{Float64,2}, ::Val{false}) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/cholesky.jl:258
#  [5] #cholesky#129 at ./none:0 [inlined]
#  [6] cholesky at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/cholesky.jl:348 [inlined] (repeats 2 times)
#  [7] Reconstruct(::SpectralPOP.NystromSketch) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/solvers/SketchyCGAL/NystromSketch.jl:72
#  [8] #CGAL#11(::Float64, ::String, ::Bool, ::typeof(SpectralPOP.CGAL), ::UInt32, ::SpectralPOP.var"#Primitive1#33"{Array{Float64,2}}, ::SpectralPOP.var"#Primitive2#34"{Bool,Int64,SparseArrays.SparseMatrixCSC{Float64,Int64},SparseArrays.SparseMatrixCSC{UInt64,Int64}}, ::SpectralPOP.var"#Primitive3#35"{Bool,Int64,SparseArrays.SparseMatrixCSC{Float64,Int64}}, ::Array{Float32,1}, ::Array{Float64,1}, ::UInt16, ::UInt64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/solvers/SketchyCGAL/CGAL.jl:91
#  [9] #CGAL at ./none:0 [inlined]
#  [10] #SpectralSDP#30(::String, ::String, ::Float64, ::Bool, ::Bool, ::typeof(SpectralPOP.SpectralSDP), ::Int64, ::Int64, ::Array{Float64,1}, ::SparseArrays.SparseMatrixCSC{Float64,Int64}, ::Array{UInt64,1}, ::Array{Float64,1}, ::SparseArrays.SparseMatrixCSC{UInt64,Int64}, ::Float64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:158
#  [11] #SpectralSDP at ./none:0 [inlined]
#  [12] macro expansion at ./util.jl:155 [inlined]
#  [13] macro expansion at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:59 [inlined]
#  [14] macro expansion at ./util.jl:155 [inlined]
#  [15] #CTP_POP#28(::String, ::String, ::Float64, ::Bool, ::Bool, ::typeof(CTP_POP), ::Array{PolyVar{true},1}, ::Polynomial{true,Float64}, ::Array{Polynomial{true,Float64},1}, ::Int64, ::Float64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/src/POP_CTP.jl:48
#  [16] #CTP_POP at ./none:0 [inlined]
#  [17] test_random_dense_quadratic_on_sphere(::Int64) at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/test/poly_opt/test_random_dense_quadratic_on_sphere.jl:57
#  [18] top-level scope at /home/hoanganh/Desktop/math-topics/SpectralPOP/codes/SpectralPOP/test/poly_opt/test_random_dense_quadratic_on_sphere.jl:71
#  [19] include at ./boot.jl:328 [inlined]
#  [20] include_relative(::Module, ::String) at ./loading.jl:1105
#  [21] include(::Module, ::String) at ./Base.jl:31
#  [22] include(::String) at ./client.jl:424
#  [23] top-level scope at In[4]:1
