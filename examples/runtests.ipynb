# %%
println("****Test polynomial optimization****")

using DynamicPolynomials

@polyvar x[1:2] # variables

f=x[1]^2+0.5*x[1]*x[2]-0.25*x[2]^2+0.75*x[1]-0.3*x[2] # objective function

R=1.0 # squared radius of a sphere constraint
h=[R-sum(x.^2);(x[1]-1.0)*x[2]] # equality constraints (including the sphere constraint)

k=2 # relaxed order

include("../src/SpectralPOP.jl")
using .SpectralPOP

g=Vector{Polynomial{true,Float64}}([])
opt_val = SpectralPOP.SumofSquares_POP_WithExtraction(x,f,g,h,k) # SumOfSquares.jl + Mosek
println()
println(".................................")
println()


# get approximations of the optimal value and an optimal solution
opt_val,opt_sol = SpectralPOP.CTP_POP(x,f,h,k,R,method="LMBM",EigAlg="Arpack",tol=1e-5)# Limited Memory Bundle Method
println()
println(".................................")
println()
opt_val,opt_sol = SpectralPOP.CTP_POP(x,f,h,k,R,method="SketchyCGAL",EigAlg="Normal",tol=1e-3)# Limited Memory Bundle Method
# Out:
# ****Test polynomial optimization****
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=0.2499999989810142
# Atomic measure on the variables x[1], x[2] with 1 atoms:
#  at [-1.000000003373059, 0.0] with weight 0.9999999960287472
#   0.018100 seconds (10.15 k allocations: 1.167 MiB)
#
# .................................
# WARNING: replacing module SpectralPOP.
# WARNING: using SpectralPOP.CTP_POP in module Main conflicts with an existing identifier.
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=6
#   Number of equality trace constraints: m=19
#   0.057538 seconds (51.50 k allocations: 2.595 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       19
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        18
# N. func. eval.:  21
# Final value:     -0.250000
# Execution time:  0.067719
#   0.237705 seconds (255.50 k allocations: 14.496 MiB)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=0.24999969546589912
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [-0.9999869163168986, -9.51675308441568e-5]
#   check gap of lower bound  = 6.008123929646114e-5
#   check equality constraint 1 = 2.6158138161092026e-5
#   check equality constraint 2 = 0.0001903338165464985
# ####################################
# Optimal solution: opt_sol = [-0.9999869163168986, -9.51675308441568e-5]
# ####################################
#   0.000627 seconds (1.28 k allocations: 42.250 KiB)
#   0.296315 seconds (309.25 k allocations: 17.153 MiB)
#
# .................................
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=6
#   Number of equality trace constraints: m=19
#   0.000254 seconds (1.00 k allocations: 74.156 KiB)
# **SketchyCGAL solver:
# - SketchyCGAL SDP Solver - Beta.V.0.0
# --------------------------
#  iter=1
#  stopObj=5.083434530661883
#  stopFeas=1.0
#  primalObj=-0.4946660733025033
# --------------------------
#  iter=2
#  stopObj=44.11303947900406
#  stopFeas=4.614904075089945
#  primalObj=1.082718037720084
# --------------------------
#  iter=4
#  stopObj=9.561658466593478
#  stopFeas=1.351137720848584
#  primalObj=0.9433206598875008
# --------------------------
#  iter=8
#  stopObj=11.118166240407099
#  stopFeas=1.0063030928263614
#  primalObj=0.4370965381446755
# --------------------------
#  iter=16
#  stopObj=6.077117433838934
#  stopFeas=0.41730926208844554
#  primalObj=0.5535694506935022
# --------------------------
#  iter=32
#  stopObj=0.6297451287582363
#  stopFeas=0.12302717490274885
#  primalObj=0.5680749368094162
# --------------------------
#  iter=64
#  stopObj=1.0727081030635042
#  stopFeas=0.05679765766397154
#  primalObj=0.6483165517446107
# --------------------------
#  iter=128
#  stopObj=0.8247310078945111
#  stopFeas=0.029056394080712665
#  primalObj=0.5627808153869432
# --------------------------
#  iter=256
#  stopObj=0.2552563312634624
#  stopFeas=0.010475689577861678
#  primalObj=0.5101070593517695
# --------------------------
#  iter=512
#  stopObj=-0.6217218333840757
#  stopFeas=0.013621281564140207
#  primalObj=0.4730538635501865
# --------------------------
#  iter=1024
#  stopObj=0.24814783982054878
#  stopFeas=0.004372444950398804
#  primalObj=0.4291722183655974
# --------------------------
#  iter=2048
#  stopObj=-0.08638458141308952
#  stopFeas=0.0023691159772944136
#  primalObj=0.4405924037636392
# --------------------------
#  iter=4096
#  stopObj=0.2656030133742005
#  stopFeas=0.002407486727544083
#  primalObj=0.4727253401796262
# --------------------------
#  iter=8192
#  stopObj=0.15584804409398956
#  stopFeas=0.001431032481061665
#  primalObj=0.5098210802548494
# --------------------------
#  iter=16384
#  stopObj=0.1985479154189717
#  stopFeas=0.0010333445003513065
#  primalObj=0.5436256017418575
# --------------------------
#  iter=32768
#  stopObj=-0.5839637666118511
#  stopFeas=0.0009937879722514318
#  primalObj=0.5830833217329235
# --------------------------
#  iter=65536
#  stopObj=-0.46844404354966507
#  stopFeas=0.0006870971085529919
#  primalObj=0.6206574792163023

# %%
println("****Test polynomial system****")

using DynamicPolynomials

@polyvar x[1:2] # variables

# mickey equations
h=[x[1]^2 + 4*x[2]^2 - 4;
        2*x[2]^2 - x[1]]

L=10 # squared radius of a ball centered at origin containing at least one real root
k=1 # relaxed order

include("../src/SpectralPOP.jl")
using .SpectralPOP

# get a real root
root = SpectralPOP.ASC_PolySys(x,h,k,L,method="LMBM",EigAlg="Arpack",tol=1e-5)
# Out:
# ****Test polynomial system****
# ------------------------------------
# Determine omega1:
# WARNING: replacing module SpectralPOP.
# WARNING: using SpectralPOP.CTP_POP in module Main conflicts with an existing identifier.
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=4
#   0.047598 seconds (51.25 k allocations: 2.572 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       4
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     3
# N. iter.:        244
# N. func. eval.:  2092
# Final value:     -1.218241
# Execution time:  0.171402
#   0.364104 seconds (468.61 k allocations: 25.995 MiB)
# 4
# (4,)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=1.218240666866828
# ====================================
# Dimension of the null space of Gram matrix = 3
#   0.000160 seconds (180 allocations: 13.938 KiB)
#   0.418351 seconds (521.79 k allocations: 28.642 MiB)
# omega1 = 1.218240666866828
# ------------------------------------
# ------------------------------------
# Determine omega2:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=5
#   0.000466 seconds (940 allocations: 67.484 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       5
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     3
# N. iter.:        59
# N. func. eval.:  206
# Final value:     -1.502764
# Execution time:  0.011948
#   0.012657 seconds (22.89 k allocations: 1.191 MiB)
# 4
# (5,)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=1.5027641555169873
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [0.39196922461675693, 0.2497251484950383, 0.0]
#   check gap of lower bound  = 0.7862119296695333
#   check equality constraint 1 = 0.7839974771624694
#   check equality constraint 2 = 0.0030904722101374182
#   check equality constraint 3 = 0.0007737473338286782
#   check equality constraint 4 = 0.7861765932628113
#   0.000539 seconds (1.12 k allocations: 37.531 KiB)
#   0.014150 seconds (26.07 k allocations: 1.317 MiB)
# omega2 = 1.5027641555169873
# ------------------------------------
# ------------------------------------
# Determine omega3:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=4
#   Number of equality trace constraints: m=6
#   0.000201 seconds (826 allocations: 58.844 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       6
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        8
# N. func. eval.:  8
# Final value:     -0.227539
# Execution time:  0.000000
#   0.001139 seconds (2.56 k allocations: 85.000 KiB)
# 4
# (6,)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=0.22753890343624888
# ====================================
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [0.3908347449078756, 0.2485901169315699, 0.8862422260914993]
#   check gap of lower bound  = 4.922824837555462e-5
#   check equality constraint 1 = 2.5872629128120828e-5
#   check equality constraint 2 = 6.0017228589337446e-5
#   check equality constraint 3 = 1.294208124988372e-6
#   check equality constraint 4 = 6.397068829266939e-5
#   check equality constraint 5 = 2.9737990744793663e-5
# ####################################
# Optimal solution: opt_sol = [0.3908347449078756, 0.2485901169315699, 0.8862422260914993]
# ####################################
#   0.000690 seconds (1.72 k allocations: 49.672 KiB)
#   0.002495 seconds (6.24 k allocations: 220.438 KiB)
# omega3 = 0.22753890343624888
# ------------------------------------
# ------
#   0.997429 seconds (971.04 k allocations: 50.989 MiB)
#   1.475903 seconds (1.32 M allocations: 68.357 MiB)
# 2-element Array{Float64,1}:
#  1.2359279826397824
#  0.7861109733113487
